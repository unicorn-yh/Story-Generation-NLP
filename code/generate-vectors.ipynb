# %% [markdown]
# Generate Vectors using Skipthoughts

# %%
import pandas as pd
import numpy as np
import numpy as np
from skip_thoughts import configuration
from skip_thoughts import encoder_manager
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
train_stories = pd.read_csv("story_generation_dataset/ROCStories_train.csv", encoding="utf8")
test_stories = pd.read_csv("story_generation_dataset/ROCStories_test.csv", encoding="utf8")
val_stories = pd.read_csv("story_generation_dataset/ROCStories_val.csv", encoding="utf8")

# %%
train_stories = train_stories.append(val_stories)
train_stories = train_stories[:2000]
test_stories = train_stories[:500]

# %%
train_stories.head()
# Out:
#                                 storyid               storytitle  \
# 0  8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd   David Drops the Weight
# 1  0beabab2-fb49-460e-a6e6-f35a202e3348              Frustration
# 2  87da1a22-df0b-410c-b186-439700b70ba6       Marcus Buys Khakis
# 3  2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9       Different Opinions
# 4  c71bb23b-7731-4233-8298-76ba6886cee1  Overcoming shortcomings
#
#                                            sentence1  \
# 0  David noticed he had put on a lot of weight re...
# 1                       Tom had a very short temper.
# 2  Marcus needed clothing for a business casual e...
# 3  Bobby thought Bill should buy a trailer and ha...
# 4          John was a pastor with a very bad memory.
#
#                                            sentence2  \
# 0  He examined his habits to try and figure out t...
# 1               One day a guest made him very angry.
# 2  All of his clothes were either too formal or t...
# 3  Bill thought a truck would be better for what ...
# 4  He tried to memorize his sermons many days in ...
#
#                                            sentence3  \
# 0  He realized he'd been eating too much fast foo...
# 1        He punched a hole in the wall of his house.
# 2                He decided to buy a pair of khakis.
# 3  Bobby pointed out two vehicles were much more ...
# 4  He decided to learn to sing to overcome his ha...
#
#                                            sentence4  \
# 0  He stopped going to burger places and started ...
# 1        Tom's guest became afraid and left quickly.
# 2              The pair he bought fit him perfectly.
# 3  Bill was set in his ways with conventional thi...
# 4  He then made all his sermons into music and sa...
#
#                                            sentence5
# 0  After a few weeks, he started to feel much bet...
# 1  Tom sat on his couch filled with regret about ...
# 2  Marcus was happy to have the right clothes for...
# 3  He ended up buying the truck he wanted despite...
# 4      His congregation was delighted and so was he.

# %%
test_stories.head()
# Out:
#                                 storyid               storytitle  \
# 0  8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd   David Drops the Weight
# 1  0beabab2-fb49-460e-a6e6-f35a202e3348              Frustration
# 2  87da1a22-df0b-410c-b186-439700b70ba6       Marcus Buys Khakis
# 3  2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9       Different Opinions
# 4  c71bb23b-7731-4233-8298-76ba6886cee1  Overcoming shortcomings
#
#                                            sentence1  \
# 0  David noticed he had put on a lot of weight re...
# 1                       Tom had a very short temper.
# 2  Marcus needed clothing for a business casual e...
# 3  Bobby thought Bill should buy a trailer and ha...
# 4          John was a pastor with a very bad memory.
#
#                                            sentence2  \
# 0  He examined his habits to try and figure out t...
# 1               One day a guest made him very angry.
# 2  All of his clothes were either too formal or t...
# 3  Bill thought a truck would be better for what ...
# 4  He tried to memorize his sermons many days in ...
#
#                                            sentence3  \
# 0  He realized he'd been eating too much fast foo...
# 1        He punched a hole in the wall of his house.
# 2                He decided to buy a pair of khakis.
# 3  Bobby pointed out two vehicles were much more ...
# 4  He decided to learn to sing to overcome his ha...
#
#                                            sentence4  \
# 0  He stopped going to burger places and started ...
# 1        Tom's guest became afraid and left quickly.
# 2              The pair he bought fit him perfectly.
# 3  Bill was set in his ways with conventional thi...
# 4  He then made all his sermons into music and sa...
#
#                                            sentence5
# 0  After a few weeks, he started to feel much bet...
# 1  Tom sat on his couch filled with regret about ...
# 2  Marcus was happy to have the right clothes for...
# 3  He ended up buying the truck he wanted despite...
# 4      His congregation was delighted and so was he.

# %%
print('Train Dataset')
print(train_stories.values.shape)
train_array = train_stories.values[:,1:].reshape(-1).tolist()
print(len(train_array))
train_array[:10]
# Out:
# Train Dataset
# (2000, 7)
# 12000
# ['David Drops the Weight',
#  'David noticed he had put on a lot of weight recently.',
#  'He examined his habits to try and figure out the reason.',
#  "He realized he'd been eating too much fast food lately.",
#  'He stopped going to burger places and started a vegetarian diet.',
#  'After a few weeks, he started to feel much better.',
#  'Frustration',
#  'Tom had a very short temper.',
#  'One day a guest made him very angry.',
#  'He punched a hole in the wall of his house.']

# %%
print('Test Dataset')
print(test_stories.values.shape)
test_array = test_stories.values[:,1:].reshape(-1).tolist()
print(len(test_array))
# Out:
# Test Dataset
# (500, 7)
# 3000

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# bidirectional skip thoughts
VOCAB_FILE = "skip_thoughts/pretrained/skip_thoughts_bi_2017_02_16/vocab.txt"
EMBEDDING_MATRIX_FILE = "skip_thoughts/pretrained/skip_thoughts_bi_2017_02_16/embeddings.npy"
CHECKPOINT_PATH = "skip_thoughts/pretrained/skip_thoughts_bi_2017_02_16/model.ckpt-500008"
encoder = encoder_manager.EncoderManager()
encoder.load_model(configuration.model_config(bidirectional_encoder=True),
                   vocabulary_file=VOCAB_FILE,
                   embedding_matrix_file=EMBEDDING_MATRIX_FILE,
                   checkpoint_path=CHECKPOINT_PATH)
# Out:
# INFO:tensorflow:Reading vocabulary from skip_thoughts/pretrained/skip_thoughts_bi_2017_02_16/vocab.txt
# INFO:tensorflow:Loaded vocabulary with 930914 words.
# INFO:tensorflow:Loading embedding matrix from skip_thoughts/pretrained/skip_thoughts_bi_2017_02_16/embeddings.npy
# INFO:tensorflow:Loaded embedding matrix with shape (930914, 620)
# INFO:tensorflow:Building model.
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:71: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:127: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:230: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:231: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:246: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From d:\Downloads\Python3.7\lib\site-packages\tensorflow_core\python\ops\rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\ops\gru_cell.py:117: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:47: The name tf.svd is deprecated. Please use tf.linalg.svd instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:47: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From d:\Downloads\Python3.7\lib\site-packages\tensorflow_core\python\ops\rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_model.py:360: The name tf.train.create_global_step is deprecated. Please use tf.compat.v1.train.create_global_step instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_encoder.py:151: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\skip_thoughts_encoder.py:122: The name tf.gfile.IsDirectory is deprecated. Please use tf.io.gfile.isdir instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\encoder_manager.py:85: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From d:\Project\Story-Generation-NLP\skip_thoughts\encoder_manager.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# INFO:tensorflow:Loading model from checkpoint: skip_thoughts/pretrained/skip_thoughts_bi_2017_02_16/model.ckpt-500008
# INFO:tensorflow:Restoring parameters from skip_thoughts/pretrained/skip_thoughts_bi_2017_02_16/model.ckpt-500008
# INFO:tensorflow:Successfully loaded checkpoint: model.ckpt-500008

# %%
vectors_train = encoder.encode(train_array)
np.save("data/train_vectors", vectors_train)
np.save("data/train_sentences", train_array)

# %%
vectors_test = encoder.encode(test_array)
np.save("data/test_vectors", vectors_test)
np.save("data/test_sentences", test_array)

# %%
test_vectors = np.load("data/test_vectors.npy")
test_sentences = np.load("data/test_sentences.npy")

def get_nearest(qvec, vectors, array, k=5):
    #qvec /= norm(qvec)
    scores = np.dot(qvec, vectors.T).flatten()
    sorted_args = np.argsort(scores)[::-1]
    sentences = [array[a] for a in sorted_args[:k]]
    print ('DATA: ',end="")
    for i, s in enumerate(sentences):
        print (s,sorted_args[i])

for i,j in enumerate(test_vectors):
    get_nearest(test_vectors[i], test_vectors, test_sentences, k=1)
    print("LABEL:", test_sentences[i+1], i+1, end="\n\n")
# Out:
# DATA: David Drops the Weight 0
# LABEL: David noticed he had put on a lot of weight recently. 1
#
# DATA: David noticed he had put on a lot of weight recently. 1
# LABEL: He examined his habits to try and figure out the reason. 2
#
# DATA: He examined his habits to try and figure out the reason. 2
# LABEL: He realized he'd been eating too much fast food lately. 3
#
# DATA: He realized he'd been eating too much fast food lately. 3
# LABEL: He stopped going to burger places and started a vegetarian diet. 4
#
# DATA: He stopped going to burger places and started a vegetarian diet. 4
# LABEL: After a few weeks, he started to feel much better. 5
#
# DATA: After a few weeks, he started to feel much better. 5
# LABEL: Frustration 6
#
# DATA: Frustration 6
# LABEL: Tom had a very short temper. 7
#
# DATA: Tom had a very short temper. 7
# LABEL: One day a guest made him very angry. 8
#
# DATA: One day a guest made him very angry. 8
# LABEL: He punched a hole in the wall of his house. 9
#
# DATA: He punched a hole in the wall of his house. 9
# LABEL: Tom's guest became afraid and left quickly. 10
#
# DATA: Tom's guest became afraid and left quickly. 10
# LABEL: Tom sat on his couch filled with regret about his actions. 11
#
# DATA: Tom sat on his couch filled with regret about his actions. 11
# LABEL: Marcus Buys Khakis 12
#
# DATA: Marcus Buys Khakis 12
# LABEL: Marcus needed clothing for a business casual event. 13
#
# DATA: Marcus needed clothing for a business casual event. 13
# LABEL: All of his clothes were either too formal or too casual. 14
#
# DATA: All of his clothes were either too formal or too casual. 14
# LABEL: He decided to buy a pair of khakis. 15
#
# DATA: He decided to buy a pair of khakis. 15
# LABEL: The pair he bought fit him perfectly. 16
#
# DATA: The pair he bought fit him perfectly. 16
# LABEL: Marcus was happy to have the right clothes for the event. 17
#
# DATA: Marcus was happy to have the right clothes for the event. 17
# LABEL: Different Opinions 18
#
# DATA: Different Opinions 18
# LABEL: Bobby thought Bill should buy a trailer and haul it with his car. 19
#
# DATA: Bobby thought Bill should buy a trailer and haul it with his car. 19
# LABEL: Bill thought a truck would be better for what he needed. 20
#
# DATA: Bill thought a truck would be better for what he needed. 20
# LABEL: Bobby pointed out two vehicles were much more expensive. 21
#
# DATA: Bobby pointed out two vehicles were much more expensive. 21
# LABEL: Bill was set in his ways with conventional thinking. 22
#
# DATA: Bill was set in his ways with conventional thinking. 22
# LABEL: He ended up buying the truck he wanted despite Bobby's advice. 23
#
# DATA: He ended up buying the truck he wanted despite Bobby's advice. 23
# LABEL: Overcoming shortcomings 24
#
# DATA: Overcoming shortcomings 24
# LABEL: John was a pastor with a very bad memory. 25
#
# DATA: John was a pastor with a very bad memory. 25
# LABEL: He tried to memorize his sermons many days in advance but to no avail. 26
#
# DATA: He tried to memorize his sermons many days in advance but to no avail. 26
# LABEL: He decided to learn to sing to overcome his handicap. 27
#
# DATA: He decided to learn to sing to overcome his handicap. 27
# LABEL: He then made all his sermons into music and sang them on Sundays. 28
#
# DATA: He then made all his sermons into music and sang them on Sundays. 28
# LABEL: His congregation was delighted and so was he. 29
#
# DATA: His congregation was delighted and so was he. 29
# LABEL: Melody's trip to the aquarium. 30
#
# DATA: Melody's trip to the aquarium. 30
# LABEL: Melody's parents surprised her with a trip to the big aquarium. 31
#
# DATA: Melody's parents surprised her with a trip to the big aquarium. 31
# LABEL: Melody took a nap during the two hour car ride to the aquarium. 32
#
# DATA: Melody took a nap during the two hour car ride to the aquarium. 32
# LABEL: When they arrived, Melody was energetic and excited. 33
#
# DATA: When they arrived, Melody was energetic and excited. 33
# LABEL: At the aquarium Melody saw sharks, tropical fish and many others. 34
#
# DATA: At the aquarium Melody saw sharks, tropical fish and many others. 34
# LABEL: After five hours at the aquarium, Melody and her family drove home. 35
#
# DATA: After five hours at the aquarium, Melody and her family drove home. 35
# LABEL: Pop Quiz 36
#
# DATA: Pop Quiz 36
# LABEL: The math teacher announced a pop quiz as class began. 37
#
# DATA: The math teacher announced a pop quiz as class began. 37
# LABEL: While some students complained, he began passing out the quiz. 38
#
# DATA: While some students complained, he began passing out the quiz. 38
# LABEL: I took out my pencil and began to work. 39
#
# DATA: I took out my pencil and began to work. 39
# LABEL: About 5 minutes later, I finished. 40
#
# DATA: About 5 minutes later, I finished. 40
# LABEL: I stood up feeling confident and turned it in. 41
#
# DATA: I stood up feeling confident and turned it in. 41
# LABEL: My first girlfriend 42
#
# DATA: My first girlfriend 42
# LABEL: My first girlfriend i met on the internet. 43
#
# DATA: My first girlfriend i met on the internet. 43
# LABEL: She lives about 4 hours away from me. 44
#
# DATA: She lives about 4 hours away from me. 44
# LABEL: Finally after 2 years we met each other. 45
#
# DATA: Finally after 2 years we met each other. 45
# LABEL: She stayed with me for a week or two. 46
#
# DATA: She stayed with me for a week or two. 46
# LABEL: We decided we couldn't be apart so she moved in with me. 47
#
# DATA: We decided we couldn't be apart so she moved in with me. 47
# LABEL: Charlie Horse 48
#
# DATA: Charlie Horse 48
# LABEL: I got Charlie Horse when I was four years old. 49
#
# DATA: I got Charlie Horse when I was four years old. 49
# LABEL: He's a brown stuffed horse, and at 35 I still sleep with him at night. 50
#
# DATA: He's a brown stuffed horse, and at 35 I still sleep with him at night. 50
# LABEL: He was my best friend, and always laid at the head of my bed. 51
#
# DATA: He was my best friend, and always laid at the head of my bed. 51
# LABEL: I laid him next to me, smelling his soft fur every night. 52
#
# DATA: I laid him next to me, smelling his soft fur every night. 52
# LABEL: I liked to listen to my radio as I fell asleep cuddling him. 53
#
# DATA: I liked to listen to my radio as I fell asleep cuddling him. 53
# LABEL: Corn 54
#
# DATA: Corn 54
# LABEL: Laura loved corn. 55
#
# DATA: Laura loved corn. 55
# LABEL: So she decided to grow some in her backyard. 56
#
# DATA: So she decided to grow some in her backyard. 56
# LABEL: The whole process of growing them made her very excited. 57
#
# DATA: The whole process of growing them made her very excited. 57
# LABEL: But she realized that they required too much water. 58
#
# DATA: But she realized that they required too much water. 58
# LABEL: So Laura quickly abandoned her corn garden idea. 59
#
# DATA: So Laura quickly abandoned her corn garden idea. 59
# LABEL: New Hair Color 60
#
# DATA: New Hair Color 60
# LABEL: Andy was invited to a Halloween party. 61
#
# DATA: Andy was invited to a Halloween party. 61
# LABEL: Andy figured that for dramatic effect, he should color his hair. 62
#
# DATA: Andy figured that for dramatic effect, he should color his hair. 62
# LABEL: Since Andy's costume was green, Andy decided on that color. 63
#
# DATA: Since Andy's costume was green, Andy decided on that color. 63
# LABEL: After the stylist finished the coloring, Andy regretted it. 64
#
# DATA: After the stylist finished the coloring, Andy regretted it. 64
# LABEL: Andy was disappointed with his new, bold, green hair color. 65
#
# DATA: Andy was disappointed with his new, bold, green hair color. 65
# LABEL: Winner 66
#
# DATA: Winner 66
# LABEL: Luke was playing hockey at school. 67
#
# DATA: Luke was playing hockey at school. 67
# LABEL: The game was tied and almost over. 68
#
# DATA: The game was tied and almost over. 68
# LABEL: Then Luke made the winning shot! 69
#
# DATA: Then Luke made the winning shot! 69
# LABEL: Everybody cheered! 70
#
# DATA: Everybody cheered! 70
# LABEL: Luke was so proud of himself! 71
#
# DATA: Luke was so proud of himself! 71
# LABEL: Cross country 72
#
# DATA: Cross country 72
# LABEL: Robbie was competing in a cross country meet. 73
#
# DATA: Robbie was competing in a cross country meet. 73
# LABEL: He was halfway through when his leg cramped up. 74
#
# DATA: He was halfway through when his leg cramped up. 74
# LABEL: Robbie wasn't sure he could go on. 75
#
# DATA: Robbie wasn't sure he could go on. 75
# LABEL: He stopped for a minute and stretched his bad leg. 76
#
# DATA: He stopped for a minute and stretched his bad leg. 76
# LABEL: Robbie began to run again and finished the race in second place. 77
#
# DATA: Robbie began to run again and finished the race in second place. 77
# LABEL: Traffic Troubles 78
#
# DATA: Traffic Troubles 78
# LABEL: Jude was very excited about his college graduation ceremony. 79
#
# DATA: Jude was very excited about his college graduation ceremony. 79
# LABEL: On the way to the arena, he got stuck in traffic. 80
#
# DATA: On the way to the arena, he got stuck in traffic. 80
# LABEL: He only had an hour before the ceremony started. 81
#
# DATA: He only had an hour before the ceremony started. 81
# LABEL: He thought he wasn't going to be able to make it in time. 82
#
# DATA: He thought he wasn't going to be able to make it in time. 82
# LABEL: Luckily, the traffic cleared up in time for him to get to the ceremony. 83
#
# DATA: Luckily, the traffic cleared up in time for him to get to the ceremony. 83
# LABEL: Not Santa 84
#
# DATA: Not Santa 84
# LABEL: Beth sent a letter to Santa Claus. 85
#
# DATA: Beth sent a letter to Santa Claus. 85
# LABEL: She received a letter back in the mail. 86
#
# DATA: She received a letter back in the mail. 86
# LABEL: Beth did not think that it sounded like the real Santa. 87
#
# DATA: Beth did not think that it sounded like the real Santa. 87
# LABEL: She sent another letter calling that Santa a fake. 88
#
# DATA: She sent another letter calling that Santa a fake. 88
# LABEL: She did not receive another letter back in the mail. 89
#
# DATA: She did not receive another letter back in the mail. 89
# LABEL: Miss Fussy 90
#
# DATA: Miss Fussy 90
# LABEL: Our granddaughter Anna is very fussy about her clothes. 91
#
# DATA: Our granddaughter Anna is very fussy about her clothes. 91
# LABEL: She is only two, but wants to pick her outfits. 92
#
# DATA: She is only two, but wants to pick her outfits. 92
# LABEL: Today her mom wanted Anna to wear a dress. 93
#
# DATA: Today her mom wanted Anna to wear a dress. 93
# LABEL: Anna started crying. 94
#
# DATA: Anna started crying. 94
# LABEL: They let her wear a t-shirt and shorts instead. 95
#
# DATA: They let her wear a t-shirt and shorts instead. 95
# LABEL: Getting to the Store 96
#
# DATA: Getting to the Store 96
# LABEL: Jake needed a ride to the store. 97
#
# DATA: Jake needed a ride to the store. 97
# LABEL: His girlfriend was working and wouldn't take him. 98
#
# DATA: His girlfriend was working and wouldn't take him. 98
# LABEL: His brother was in the middle of a movie and said no. 99
#
# DATA: His brother was in the middle of a movie and said no. 99
# LABEL: Jake decided to take the bus to the store. 100
#
# DATA: Jake decided to take the bus to the store. 100
# LABEL: He got what he needed all by himself. 101
#
# DATA: He got what he needed all by himself. 101
# LABEL: The Sale 102
#
# DATA: The Sale 102
# LABEL: I'd been looking for a stand for my TV. 103
#
# DATA: I'd been looking for a stand for my TV. 103
# LABEL: I looked everywhere, but the ones I saw were expensive. 104
#
# DATA: I looked everywhere, but the ones I saw were expensive. 104
# LABEL: I happened upon a yard sale on my way home. 105
#
# DATA: I happened upon a yard sale on my way home. 105
# LABEL: She had a stand that was perfect, and cheap. 106
#
# DATA: She had a stand that was perfect, and cheap. 106
# LABEL: It looks great in my den. 107
#
# DATA: It looks great in my den. 107
# LABEL: Prescription 108
#
# DATA: Prescription 108
# LABEL: Sally had a root canal this morning, as she had a damaged root. 109
#
# DATA: Sally had a root canal this morning, as she had a damaged root. 109
# LABEL: After the procedure, the dentist wrote her a prescription. 110
#
# DATA: After the procedure, the dentist wrote her a prescription. 110
# LABEL: She headed straight to the pharmacy to fill her medication. 111
#
# DATA: She headed straight to the pharmacy to fill her medication. 111
# LABEL: She handed the prescription to the technician and waited patiently. 112
#
# DATA: She handed the prescription to the technician and waited patiently. 112
# LABEL: The technician called her name and she paid for the prescription. 113
#
# DATA: The technician called her name and she paid for the prescription. 113
# LABEL: Storm 114
#
# DATA: Storm 114
# LABEL: My dog is terrified of thunder. 115
#
# DATA: My dog is terrified of thunder. 115
# LABEL: There was a storm today. 116
#
# DATA: There was a storm today. 116
# LABEL: He came running into my office. 117
#
# DATA: He came running into my office. 117
# LABEL: He hid in the kneehole of my desk, trembling. 118
#
# DATA: He hid in the kneehole of my desk, trembling. 118
# LABEL: Once the storm was over, he acted like a brave dog again. 119
#
# DATA: Once the storm was over, he acted like a brave dog again. 119
# LABEL: Children's Show 120
#
# DATA: Children's Show 120
# LABEL: Mark and Jo were brainstorming ideas for a children's show. 121
#
# DATA: Mark and Jo were brainstorming ideas for a children's show. 121
# LABEL: Mark suggested that a monster attacks the children. 122
#
# DATA: Mark suggested that a monster attacks the children. 122
# LABEL: Jo laughed because he thought Mark was joking. 123
#
# DATA: Jo laughed because he thought Mark was joking. 123
# LABEL: Mark was confused because he thought it was a great idea. 124
#
# DATA: Mark was confused because he thought it was a great idea. 124
# LABEL: Mark left in a huff for having his ideas mocked. 125
#
# DATA: Mark left in a huff for having his ideas mocked. 125
# LABEL: Parade Float 126
#
# DATA: Parade Float 126
# LABEL: Ben's Boy Scout Troop worked for weeks on a float. 127
#
# DATA: Ben's Boy Scout Troop worked for weeks on a float. 127
# LABEL: It was going to be in the town's July 4th parade. 128
#
# DATA: It was going to be in the town's July 4th parade. 128
# LABEL: They got it finished just in time. 129
#
# DATA: They got it finished just in time. 129
# LABEL: It was big enough for his whole troop to ride on. 130
#
# DATA: It was big enough for his whole troop to ride on. 130
# LABEL: They felt proud as they went down the street as people clapped. 131
#
# DATA: They felt proud as they went down the street as people clapped. 131
# LABEL: Francis Ties a Tie 132
#
# DATA: Francis Ties a Tie 132
# LABEL: Francis has always wanted to learn how to tie a necktie. 133
#
# DATA: Francis has always wanted to learn how to tie a necktie. 133
# LABEL: He decides to practice until he can tie one. 134
#
# DATA: He decides to practice until he can tie one. 134
# LABEL: At first he finds it very difficult. 135
#
# DATA: At first he finds it very difficult. 135
# LABEL: But eventually he is able to tie a necktie very well. 136
#
# DATA: But eventually he is able to tie a necktie very well. 136
# LABEL: Francis is proud of himself for learning how to tie a necktie. 137
#
# DATA: Francis is proud of himself for learning how to tie a necktie. 137
# LABEL: Stepmother 138
#
# DATA: Stepmother 138
# LABEL: Eric and his wife had a daughter named Meg. 139
#
# DATA: Eric and his wife had a daughter named Meg. 139
# LABEL: Eric's wife passed away. 140
#
# DATA: Eric's wife passed away. 140
# LABEL: Eric and Meg were very sad. 141
#
# DATA: Eric and Meg were very sad. 141
# LABEL: Eric met a woman and married her 5 years after his wife died. 142
#
# DATA: Eric met a woman and married her 5 years after his wife died. 142
# LABEL: Meg is now happy with her new stepmother. 143
#
# DATA: Meg is now happy with her new stepmother. 143
# LABEL: Foreign Food 144
#
# DATA: Foreign Food 144
# LABEL: My cousin took me to a local restaurant. 145
#
# DATA: My cousin took me to a local restaurant. 145
# LABEL: We ordered a large pizza. 146
#
# DATA: We ordered a large pizza. 146
# LABEL: Since she never tasted the food there, she didn't know if it was good. 147
#
# DATA: Since she never tasted the food there, she didn't know if it was good. 147
# LABEL: I began to start sneezing. 148
#
# DATA: I began to start sneezing. 148
# LABEL: To make matters worse, I caught an allergy. 149
#
# DATA: To make matters worse, I caught an allergy. 149
# LABEL: My Diagnosis 150
#
# DATA: My Diagnosis 150
# LABEL: When I was 12 years old, my dad got angry and kicked me aggressively. 151
#
# DATA: When I was 12 years old, my dad got angry and kicked me aggressively. 151
# LABEL: Afterward, I became very ill, and tasted something metallic. 152
#
# DATA: Afterward, I became very ill, and tasted something metallic. 152
# LABEL: I went to a doctor, and was informed that one of my kidneys was dead. 153
#
# DATA: I went to a doctor, and was informed that one of my kidneys was dead. 153
# LABEL: Ever since, I've had swelling and hypertension. 154
#
# DATA: Ever since, I've had swelling and hypertension. 154
# LABEL: I started taking medications to combat the symptoms at 13. 155
#
# DATA: I started taking medications to combat the symptoms at 13. 155
# LABEL: Fred Wears Sandals 156
#
# DATA: Fred Wears Sandals 156
# LABEL: Fred noticed that he feet got very hot in the summer. 157
#
# DATA: Fred noticed that he feet got very hot in the summer. 157
# LABEL: He decided he needed new footwear. 158
#
# DATA: He decided he needed new footwear. 158
# LABEL: Fred invested in a nice new pair of sandals. 159
#
# DATA: Fred invested in a nice new pair of sandals. 159
# LABEL: He loved wearing his new sandals. 160
#
# DATA: He loved wearing his new sandals. 160
# LABEL: Fred was glad that his feet no longer got hot in the summer. 161
#
# DATA: Fred was glad that his feet no longer got hot in the summer. 161
# LABEL: Maine 162
#
# DATA: Maine 162
# LABEL: Last year I took a day trip to see a friend in Maine. 163
#
# DATA: Last year I took a day trip to see a friend in Maine. 163
# LABEL: I took the Amtrak from Boston to Saco, Maine. 164
#
# DATA: I took the Amtrak from Boston to Saco, Maine. 164
# LABEL: We had lunch at Gritty's in Portland. 165
#
# DATA: We had lunch at Gritty's in Portland. 165
# LABEL: My friend drove me back to the train station. 166
#
# DATA: My friend drove me back to the train station. 166
# LABEL: I had a nice time and will visit my friend this year. 167
#
# DATA: I had a nice time and will visit my friend this year. 167
# LABEL: Heather cooks Tacos for the first time. 168
#
# DATA: Heather cooks Tacos for the first time. 168
# LABEL: Heather and her family really wanted tacos for dinner. 169
#
# DATA: Heather and her family really wanted tacos for dinner. 169
# LABEL: Two of the children wanted chicken tacos. 170
#
# DATA: Two of the children wanted chicken tacos. 170
# LABEL: The other two children wanted beef. 171
#
# DATA: The other two children wanted beef. 171
# LABEL: Heather took great care preparing all the tacos that each wanted. 172
#
# DATA: Heather took great care preparing all the tacos that each wanted. 172
# LABEL: Everyone sat down at dinner and enjoyed eating the tacos together. 173
#
# DATA: Everyone sat down at dinner and enjoyed eating the tacos together. 173
# LABEL: Suet 174
#
# DATA: Suet 174
# LABEL: Anna was filling her bird feeders. 175
#
# DATA: Anna was filling her bird feeders. 175
# LABEL: But a chunk of suet fell onto the ground. 176
#
# DATA: But a chunk of suet fell onto the ground. 176
# LABEL: Her dog rushed over and lapped it up! 177
#
# DATA: Her dog rushed over and lapped it up! 177
# LABEL: Anna was astonished. 178
#
# DATA: Anna was astonished. 178
# LABEL: She had no idea dogs loved bird food! 179
#
# DATA: She had no idea dogs loved bird food! 179
# LABEL: No Connection 180
#
# DATA: No Connection 180
# LABEL: James had an Xbox 360. 181
#
# DATA: James had an Xbox 360. 181
# LABEL: His friends had Xbox accounts online. 182
#
# DATA: His friends had Xbox accounts online. 182
# LABEL: James registered, but was still unable to connect online. 183
#
# DATA: James registered, but was still unable to connect online. 183
# LABEL: He called for tech support, but they couldn't help either. 184
#
# DATA: He called for tech support, but they couldn't help either. 184
# LABEL: He realized he would need a new Xbox. 185
#
# DATA: He realized he would need a new Xbox. 185
# LABEL: The Protest 186
#
# DATA: The Protest 186
# LABEL: The people gathered to protest the court's ruling last week. 187
#
# DATA: The people gathered to protest the court's ruling last week. 187
# LABEL: They held signs and chanted loudly. 188
#
# DATA: They held signs and chanted loudly. 188
# LABEL: The police stormed in and arrested them all. 189
#
# DATA: The police stormed in and arrested them all. 189
# LABEL: Now there are more protests in surrounding towns. 190
#
# DATA: Now there are more protests in surrounding towns. 190
# LABEL: The movement is gaining momentum! 191
#
# DATA: The movement is gaining momentum! 191
# LABEL: Big Box 192
#
# DATA: Big Box 192
# LABEL: My roommate and I bought a new futon for our living room. 193
#
# DATA: My roommate and I bought a new futon for our living room. 193
# LABEL: The futon came in a huge box. 194
#
# DATA: The futon came in a huge box. 194
# LABEL: We set the box out on the curb to be picked up on trash day. 195
#
# DATA: We set the box out on the curb to be picked up on trash day. 195
# LABEL: Much to our chagrin, the garbage men left the box on the curb. 196
#
# DATA: Much to our chagrin, the garbage men left the box on the curb. 196
# LABEL: We had to take the box to the dump ourselves. 197
#
# DATA: We had to take the box to the dump ourselves. 197
# LABEL: Pot of Gold 198
#
# DATA: Pot of Gold 198
# LABEL: Bob chased after the rainbow through the fields. 199
#
# DATA: Bob chased after the rainbow through the fields. 199
# LABEL: He ran after it over forests and streams. 200
#
# DATA: He ran after it over forests and streams. 200
# LABEL: Bob thought he'd lost it behind a boulder. 201
#
# DATA: Bob thought he'd lost it behind a boulder. 201
# LABEL: He found it waiting for him on the other side. 202
#
# DATA: He found it waiting for him on the other side. 202
# LABEL: When Bob dived for the pot of gold, he woke up. 203
#
# DATA: When Bob dived for the pot of gold, he woke up. 203
# LABEL: One Way to Paris 204
#
# DATA: One Way to Paris 204
# LABEL: Soren ran through the airport, pulling her bags behind her. 205
#
# DATA: Soren ran through the airport, pulling her bags behind her. 205
# LABEL: The female voice above her announced final boarding to Soren's fligh. 206
#
# DATA: The female voice above her announced final boarding to Soren's fligh. 206
# LABEL: She yelled for them to wait as she neared her gate, waving her arms. 207
#
# DATA: She yelled for them to wait as she neared her gate, waving her arms. 207
# LABEL: The attendant at the desk gave Soren a sad, sympathetic look. 208
#
# DATA: The attendant at the desk gave Soren a sad, sympathetic look. 208
# LABEL: Nearly out of breath, Soren presented her pass and boarded the plane. 209
#
# DATA: Nearly out of breath, Soren presented her pass and boarded the plane. 209
# LABEL: Charles Graduates 210
#
# DATA: Charles Graduates 210
# LABEL: Charles had always wanted to have a college degree. 211
#
# DATA: Charles had always wanted to have a college degree. 211
# LABEL: He worked hard for many years to complete his courses. 212
#
# DATA: He worked hard for many years to complete his courses. 212
# LABEL: Finally he turned in his last college essay. 213
#
# DATA: Finally he turned in his last college essay. 213
# LABEL: All of his family attended his college graduation. 214
#
# DATA: All of his family attended his college graduation. 214
# LABEL: Charles was proud that he had a college degree. 215
#
# DATA: Charles was proud that he had a college degree. 215
# LABEL: Stacy Changes Her Mind 216
#
# DATA: Stacy Changes Her Mind 216
# LABEL: Stacy originally thought she wanted five kids. 217
#
# DATA: Stacy originally thought she wanted five kids. 217
# LABEL: She and Bob first were blessed with a daughter. 218
#
# DATA: She and Bob first were blessed with a daughter. 218
# LABEL: Two years later, they had twin girls. 219
#
# DATA: Two years later, they had twin girls. 219
# LABEL: Now, Stacy is selling all her maternity and baby clothes. 220
#
# DATA: Now, Stacy is selling all her maternity and baby clothes. 220
# LABEL: She says she has changed her mind about wanting five kids! 221
#
# DATA: She says she has changed her mind about wanting five kids! 221
# LABEL: Lance wins 222
#
# DATA: Lance wins 222
# LABEL: Lance was going to make a bet. 223
#
# DATA: Lance was going to make a bet. 223
# LABEL: He was thinking of making it a big one. 224
#
# DATA: He was thinking of making it a big one. 224
# LABEL: He was going to bet all of his savings on a Race. 225
#
# DATA: He was going to bet all of his savings on a Race. 225
# LABEL: The day of the Race is here. 226
#
# DATA: The day of the Race is here. 226
# LABEL: Lance crosses the finish line and Wins it all! 227
#
# DATA: Lance crosses the finish line and Wins it all! 227
# LABEL: Office Party 228
#
# DATA: Office Party 228
# LABEL: Larry worked at an accounting firm. 229
#
# DATA: Larry worked at an accounting firm. 229
# LABEL: It was a boring job but it paid the bills. 230
#
# DATA: It was a boring job but it paid the bills. 230
# LABEL: Larry grew tired of doing the same thing every day. 231
#
# DATA: Larry grew tired of doing the same thing every day. 231
# LABEL: He had the idea to have an office party. 232
#
# DATA: He had the idea to have an office party. 232
# LABEL: By lunch the whole office had passed out and nothing got done. 233
#
# DATA: By lunch the whole office had passed out and nothing got done. 233
# LABEL: Swimmer 234
#
# DATA: Swimmer 234
# LABEL: Ava was six years old. 235
#
# DATA: Ava was six years old. 235
# LABEL: She wanted to learn to swim. 236
#
# DATA: She wanted to learn to swim. 236
# LABEL: Her mom took her to the pool. 237
#
# DATA: Her mom took her to the pool. 237
# LABEL: There, she patiently taught Ava the basics. 238
#
# DATA: There, she patiently taught Ava the basics. 238
# LABEL: Soon Ava was paddling all by herself! 239
#
# DATA: Soon Ava was paddling all by herself! 239
# LABEL: The missing wallet 240
#
# DATA: The missing wallet 240
# LABEL: James was walking down a street one afternoon. 241
#
# DATA: James was walking down a street one afternoon. 241
# LABEL: He noticed a wallet lying on the ground. 242
#
# DATA: He noticed a wallet lying on the ground. 242
# LABEL: He decided to bring it to the police station. 243
#
# DATA: He decided to bring it to the police station. 243
# LABEL: That evening, the phone rang. 244
#
# DATA: That evening, the phone rang. 244
# LABEL: The old man had called to thank James for returning his wallet. 245
#
# DATA: The old man had called to thank James for returning his wallet. 245
# LABEL: Dog's Behavior 246
#
# DATA: Dog's Behavior 246
# LABEL: Chad's dog would always jump on people. 247
#
# DATA: Chad's dog would always jump on people. 247
# LABEL: Chad couldn't bring his dog anywhere. 248
#
# DATA: Chad couldn't bring his dog anywhere. 248
# LABEL: Chad decided to hire a dog trainer. 249
#
# DATA: Chad decided to hire a dog trainer. 249
# LABEL: The trainer taught the dog how to behave. 250
#
# DATA: The trainer taught the dog how to behave. 250
# LABEL: Chad was proud to finally show off his dog to others. 251
#
# DATA: Chad was proud to finally show off his dog to others. 251
# LABEL: Sliding Into Second 252
#
# DATA: Sliding Into Second 252
# LABEL: Karl was a good baseball player in his youth. 253
#
# DATA: Karl was a good baseball player in his youth. 253
# LABEL: As a middle-aged man, he joined an adult baseball team. 254
#
# DATA: As a middle-aged man, he joined an adult baseball team. 254
# LABEL: Karl is very competitive and will do anything to win. 255
#
# DATA: Karl is very competitive and will do anything to win. 255
# LABEL: One day, he slid into second base to beat a throw and hurt his knee. 256
#
# DATA: One day, he slid into second base to beat a throw and hurt his knee. 256
# LABEL: The injury made Karl realize that he wasn't young anymore. 257
#
# DATA: The injury made Karl realize that he wasn't young anymore. 257
# LABEL: The Roommate 258
#
# DATA: The Roommate 258
# LABEL: Nick was trying to buy a house. 259
#
# DATA: Nick was trying to buy a house. 259
# LABEL: He lived with a roommate that he couldn't trust. 260
#
# DATA: He lived with a roommate that he couldn't trust. 260
# LABEL: His stuff always ended up missing from his bedroom. 261
#
# DATA: His stuff always ended up missing from his bedroom. 261
# LABEL: He knew it had to be Nick so he decided he would move out. 262
#
# DATA: He knew it had to be Nick so he decided he would move out. 262
# LABEL: He found a place and moved out as fast as he could. 263
#
# DATA: He found a place and moved out as fast as he could. 263
# LABEL: Fat Goldfish 264
#
# DATA: Fat Goldfish 264
# LABEL: Jody bought a goldfish from the pet store. 265
#
# DATA: Jody bought a goldfish from the pet store. 265
# LABEL: She noticed that the goldfish looked quite fat. 266
#
# DATA: She noticed that the goldfish looked quite fat. 266
# LABEL: Her mom told her that the goldfish had too much to eat. 267
#
# DATA: Her mom told her that the goldfish had too much to eat. 267
# LABEL: Jody adjusted her pet's diet. 268
#
# DATA: Jody adjusted her pet's diet. 268
# LABEL: The goldfish got skinnier and healthier. 269
#
# DATA: The goldfish got skinnier and healthier. 269
# LABEL: Jane's New Job 270
#
# DATA: Jane's New Job 270
# LABEL: Jane had recently gotten a new job. 271
#
# DATA: Jane had recently gotten a new job. 271
# LABEL: She was nervous about her first day of work. 272
#
# DATA: She was nervous about her first day of work. 272
# LABEL: On the first day of work, Jane overslept. 273
#
# DATA: On the first day of work, Jane overslept. 273
# LABEL: Jane arrived at work an hour late. 274
#
# DATA: Jane arrived at work an hour late. 274
# LABEL: Jane did not make a good impression at her new job. 275
#
# DATA: Jane did not make a good impression at her new job. 275
# LABEL: The Amazon 276
#
# DATA: The Amazon 276
# LABEL: Jill was going on a trip to the amazon. 277
#
# DATA: Jill was going on a trip to the amazon. 277
# LABEL: She arrived after a flight from the US. 278
#
# DATA: She arrived after a flight from the US. 278
# LABEL: Once there she marveled at all the beauty. 279
#
# DATA: Once there she marveled at all the beauty. 279
# LABEL: It was dangerous, but exciting. 280
#
# DATA: It was dangerous, but exciting. 280
# LABEL: Jill had a wonderful time on her trip to the Amazon. 281
#
# DATA: Jill had a wonderful time on her trip to the Amazon. 281
# LABEL: Chris the Lawyer 282
#
# DATA: Chris the Lawyer 282
# LABEL: Chris is a defense attorney. 283
#
# DATA: Chris is a defense attorney. 283
# LABEL: He has a client that he must defend in court. 284
#
# DATA: He has a client that he must defend in court. 284
# LABEL: The client is not guilty. 285
#
# DATA: The client is not guilty. 285
# LABEL: Chris does his best to defend his client during his trial. 286
#
# DATA: Chris does his best to defend his client during his trial. 286
# LABEL: Chris wins the case and the client goes free. 287
#
# DATA: Chris wins the case and the client goes free. 287
# LABEL: Julie's Bad pizza 288
#
# DATA: Julie's Bad pizza 288
# LABEL: Julie was feeling hungry. 289
#
# DATA: Julie was feeling hungry. 289
# LABEL: She thought she would order some Pizza. 290
#
# DATA: She thought she would order some Pizza. 290
# LABEL: Julie order the food through an online website. 291
#
# DATA: Julie order the food through an online website. 291
# LABEL: The pizza arrived and Julie tipped the driver. 292
#
# DATA: The pizza arrived and Julie tipped the driver. 292
# LABEL: Julie went to take a bite of the pizza and it was burnt! 293
#
# DATA: Julie went to take a bite of the pizza and it was burnt! 293
# LABEL: Fear of Dogs 294
#
# DATA: Fear of Dogs 294
# LABEL: Justin was terrified of dogs. 295
#
# DATA: Justin was terrified of dogs. 295
# LABEL: His girlfriend had a dog and he wanted to feel comfortable with it. 296
#
# DATA: His girlfriend had a dog and he wanted to feel comfortable with it. 296
# LABEL: Justin went to therapy to help him get over his fear. 297
#
# DATA: Justin went to therapy to help him get over his fear. 297
# LABEL: After a few months of therapy Justin felt better around dogs. 298
#
# DATA: After a few months of therapy Justin felt better around dogs. 298
# LABEL: Justin then moved in with his girlfriend and her dog. 299
#
# DATA: Justin then moved in with his girlfriend and her dog. 299
# LABEL: Falling down 300
#
# DATA: Falling down 300
# LABEL: David was walking down the street when he felt down. 301
#
# DATA: David was walking down the street when he felt down. 301
# LABEL: He stood up and saw that his knee was bleeding. 302
#
# DATA: He stood up and saw that his knee was bleeding. 302
# LABEL: He found a handkerchief in his pants and applied it to the wound. 303
#
# DATA: He found a handkerchief in his pants and applied it to the wound. 303
# LABEL: He hopped to the nearest pharmacy stifling his pain. 304
#
# DATA: He hopped to the nearest pharmacy stifling his pain. 304
# LABEL: He then bought some peroxide and bandages to treat his knee. 305
#
# DATA: He then bought some peroxide and bandages to treat his knee. 305
# LABEL: Concert 306
#
# DATA: Concert 306
# LABEL: Nicole wanted to go to a concert in another city. 307
#
# DATA: Nicole wanted to go to a concert in another city. 307
# LABEL: Unfortunately, Nicole could not drive. 308
#
# DATA: Unfortunately, Nicole could not drive. 308
# LABEL: She asked her cousin to take her to the concert. 309
#
# DATA: She asked her cousin to take her to the concert. 309
# LABEL: Her cousin agreed to drive if Naomi bought the tickets. 310
#
# DATA: Her cousin agreed to drive if Naomi bought the tickets. 310
# LABEL: They went to the concert and had a great time. 311
#
# DATA: They went to the concert and had a great time. 311
# LABEL: Scare 312
#
# DATA: Scare 312
# LABEL: I woke from my sleep at around three in the morning. 313
#
# DATA: I woke from my sleep at around three in the morning. 313
# LABEL: I heard a scratching sound coming from inside my closet. 314
#
# DATA: I heard a scratching sound coming from inside my closet. 314
# LABEL: I turned the light on beside my bed to investigate. 315
#
# DATA: I turned the light on beside my bed to investigate. 315
# LABEL: I crept slowly toward the closet. 316
#
# DATA: I crept slowly toward the closet. 316
# LABEL: My little brother jumped out of the closet, scaring me to death. 317
#
# DATA: My little brother jumped out of the closet, scaring me to death. 317
# LABEL: Warm Beer 318
#
# DATA: Warm Beer 318
# LABEL: Ken put a bottle of beer in the freezer. 319
#
# DATA: Ken put a bottle of beer in the freezer. 319
# LABEL: He heard a popping noise. 320
#
# DATA: He heard a popping noise. 320
# LABEL: He looked in the freezer and saw the bottle had burst. 321
#
# DATA: He looked in the freezer and saw the bottle had burst. 321
# LABEL: He didn't want to wait for another beer to get cold. 322
#
# DATA: He didn't want to wait for another beer to get cold. 322
# LABEL: He drank a warm beer instead. 323
#
# DATA: He drank a warm beer instead. 323
# LABEL: Christmas Day 324
#
# DATA: Christmas Day 324
# LABEL: Christmas was Tyler's favorite holiday. 325
#
# DATA: Christmas was Tyler's favorite holiday. 325
# LABEL: On Christmas morning he ran downstairs to the tree. 326
#
# DATA: On Christmas morning he ran downstairs to the tree. 326
# LABEL: Tyler saw so many presents and could not wait to open them. 327
#
# DATA: Tyler saw so many presents and could not wait to open them. 327
# LABEL: By the time his parents woke up, Tyler had opened all his presents! 328
#
# DATA: By the time his parents woke up, Tyler had opened all his presents! 328
# LABEL: Tyler showed his parents everything Santa Claus gave him. 329
#
# DATA: Tyler showed his parents everything Santa Claus gave him. 329
# LABEL: Wendy loses her cool 330
#
# DATA: Wendy loses her cool 330
# LABEL: Wendy was working at her local fast food establishment. 331
#
# DATA: Wendy was working at her local fast food establishment. 331
# LABEL: She pretty much hated her Job. 332
#
# DATA: She pretty much hated her Job. 332
# LABEL: Wendy was having a rough day and her employees were annoying her. 333
#
# DATA: Wendy was having a rough day and her employees were annoying her. 333
# LABEL: The cook decided to defy her orders when she said go clean the trash. 334
#
# DATA: The cook decided to defy her orders when she said go clean the trash. 334
# LABEL: Wendy flew off the handle and fired him on the spot. 335
#
# DATA: Wendy flew off the handle and fired him on the spot. 335
# LABEL: Dog's Bite 336
#
# DATA: Dog's Bite 336
# LABEL: Walter was worried because his dog was showing a lot of aggression. 337
#
# DATA: Walter was worried because his dog was showing a lot of aggression. 337
# LABEL: The dog recently began snapping at other dogs and even people. 338
#
# DATA: The dog recently began snapping at other dogs and even people. 338
# LABEL: Walter consulted with his veterinarian. 339
#
# DATA: Walter consulted with his veterinarian. 339
# LABEL: The vet discovered that the dog was suffering a flea infestation. 340
#
# DATA: The vet discovered that the dog was suffering a flea infestation. 340
# LABEL: Some medication got rid of the fleas and the dog's bad mood, too. 341
#
# DATA: Some medication got rid of the fleas and the dog's bad mood, too. 341
# LABEL: The Lake 342
#
# DATA: The Lake 342
# LABEL: The couple took a romantic trip to the lake. 343
#
# DATA: The couple took a romantic trip to the lake. 343
# LABEL: They stayed in a nice cabin by the water. 344
#
# DATA: They stayed in a nice cabin by the water. 344
# LABEL: They went boating and relaxed in the hammock. 345
#
# DATA: They went boating and relaxed in the hammock. 345
# LABEL: They were happy to reconnect with each other. 346
#
# DATA: They were happy to reconnect with each other. 346
# LABEL: When they returned home, they decided to buy a lake house. 347
#
# DATA: When they returned home, they decided to buy a lake house. 347
# LABEL: Universal Studios 348
#
# DATA: Universal Studios 348
# LABEL: The family planned their first trip to Universal Studios. 349
#
# DATA: The family planned their first trip to Universal Studios. 349
# LABEL: They were excited to go on all the rides. 350
#
# DATA: They were excited to go on all the rides. 350
# LABEL: They saw a lot of the characters. 351
#
# DATA: They saw a lot of the characters. 351
# LABEL: They spent three days in the park. 352
#
# DATA: They spent three days in the park. 352
# LABEL: They were sad to come home. 353
#
# DATA: They were sad to come home. 353
# LABEL: Ketchup on fries 354
#
# DATA: Ketchup on fries 354
# LABEL: I went to a restaurant. 355
#
# DATA: I went to a restaurant. 355
# LABEL: I ordered fries. 356
#
# DATA: I ordered fries. 356
# LABEL: They put ketchup on the fries. 357
#
# DATA: They put ketchup on the fries. 357
# LABEL: I was furious at the awful site. 358
#
# DATA: I was furious at the awful site. 358
# LABEL: After complaining, I was given delicious, ketchup free fries. 359
#
# DATA: After complaining, I was given delicious, ketchup free fries. 359
# LABEL: The Craft 360
#
# DATA: The Craft 360
# LABEL: The woman decided to start a new hobby. 361
#
# DATA: The woman decided to start a new hobby. 361
# LABEL: She went to the craft store and picked out some supplies. 362
#
# DATA: She went to the craft store and picked out some supplies. 362
# LABEL: She went home and created an amazing masterpiece. 363
#
# DATA: She went home and created an amazing masterpiece. 363
# LABEL: She was very proud of her work. 364
#
# DATA: She was very proud of her work. 364
# LABEL: She displayed it in her kitchen. 365
#
# DATA: She displayed it in her kitchen. 365
# LABEL: James Plays Football 366
#
# DATA: James Plays Football 366
# LABEL: James had always wanted to try out for a sport at his school. 367
#
# DATA: James had always wanted to try out for a sport at his school. 367
# LABEL: He decided he would try out for football. 368
#
# DATA: He decided he would try out for football. 368
# LABEL: James exercised every day to be ready to try out. 369
#
# DATA: James exercised every day to be ready to try out. 369
# LABEL: After trying out, James was accepted onto the team. 370
#
# DATA: After trying out, James was accepted onto the team. 370
# LABEL: James was glad to be playing a sport at school. 371
#
# DATA: James was glad to be playing a sport at school. 371
# LABEL: Race 372
#
# DATA: Race 372
# LABEL: Josie wanted to win an important race at school. 373
#
# DATA: Josie wanted to win an important race at school. 373
# LABEL: She woke up early for a week to practice in the park. 374
#
# DATA: She woke up early for a week to practice in the park. 374
# LABEL: She also hired a coach to train with him after school. 375
#
# DATA: She also hired a coach to train with him after school. 375
# LABEL: When the race event started she was really nervous. 376
#
# DATA: When the race event started she was really nervous. 376
# LABEL: But all her hard work paid off and she made it to third place easily. 377
#
# DATA: But all her hard work paid off and she made it to third place easily. 377
# LABEL: Eggs From Above 378
#
# DATA: Eggs From Above 378
# LABEL: Kayla parked her car in front of the convenience store. 379
#
# DATA: Kayla parked her car in front of the convenience store. 379
# LABEL: She got out of the car, and began to walk towards the store. 380
#
# DATA: She got out of the car, and began to walk towards the store. 380
# LABEL: Suddenly, she got hit in the head with an egg. 381
#
# DATA: Suddenly, she got hit in the head with an egg. 381
# LABEL: She looked up and saw teenagers on top of the store. 382
#
# DATA: She looked up and saw teenagers on top of the store. 382
# LABEL: The teenagers ran away, and Kayla was left with an egg on her head. 383
#
# DATA: The teenagers ran away, and Kayla was left with an egg on her head. 383
# LABEL: The Patrol 384
#
# DATA: The Patrol 384
# LABEL: A police officer got a new patrol route. 385
#
# DATA: A police officer got a new patrol route. 385
# LABEL: He wasn't familiar with the neighborhood. 386
#
# DATA: He wasn't familiar with the neighborhood. 386
# LABEL: He spent a lot of time familiarizing himself with the street names. 387
#
# DATA: He spent a lot of time familiarizing himself with the street names. 387
# LABEL: SOon he got to know everyone in the neighborhood. 388
#
# DATA: SOon he got to know everyone in the neighborhood. 388
# LABEL: He was beginning to feel at home. 389
#
# DATA: He was beginning to feel at home. 389
# LABEL: The Thief 390
#
# DATA: The Thief 390
# LABEL: Mikey has a habit of taking items that don't belong to him. 391
#
# DATA: Mikey has a habit of taking items that don't belong to him. 391
# LABEL: Last night he stole a trailer from Henry's yard. 392
#
# DATA: Last night he stole a trailer from Henry's yard. 392
# LABEL: Henry has a camera in his yard and caught Mikey on tape. 393
#
# DATA: Henry has a camera in his yard and caught Mikey on tape. 393
# LABEL: The cops were called and took Mikey to jail. 394
#
# DATA: The cops were called and took Mikey to jail. 394
# LABEL: Mikey is now sitting in a cell thinking about his actions. 395
#
# DATA: Mikey is now sitting in a cell thinking about his actions. 395
# LABEL: Hunger 396
#
# DATA: Hunger 396
# LABEL: Roger was hungry. 397
#
# DATA: Roger was hungry. 397
# LABEL: He checked the fridge. 398
#
# DATA: He checked the fridge. 398
# LABEL: The fridge was empty. 399
#
# DATA: The fridge was empty. 399
# LABEL: Roger went to the store. 400
#
# DATA: Roger went to the store. 400
# LABEL: He came home with lots of food. 401
#
# DATA: He came home with lots of food. 401
# LABEL: Noah's Arches 402
#
# DATA: Noah's Arches 402
# LABEL: Bob stared in disbelief at the flooded basement. 403
#
# DATA: Bob stared in disbelief at the flooded basement. 403
# LABEL: All that could be seen were the stone arches above the doors. 404
#
# DATA: All that could be seen were the stone arches above the doors. 404
# LABEL: The plumber told him it flooded because the sump pump was off. 405
#
# DATA: The plumber told him it flooded because the sump pump was off. 405
# LABEL: Bob understood that was because the electricity had also been off. 406
#
# DATA: Bob understood that was because the electricity had also been off. 406
# LABEL: He enabled the electricity and the pump drained the flooded basement. 407
#
# DATA: He enabled the electricity and the pump drained the flooded basement. 407
# LABEL: Oscar Goes For A Run 408
#
# DATA: Oscar Goes For A Run 408
# LABEL: Oscar decided that he no longer wanted to be out of shape. 409
#
# DATA: Oscar decided that he no longer wanted to be out of shape. 409
# LABEL: He decided to start running outside every day. 410
#
# DATA: He decided to start running outside every day. 410
# LABEL: At first he found it very difficult. 411
#
# DATA: At first he found it very difficult. 411
# LABEL: However, over time, Oscar began to enjoy running. 412
#
# DATA: However, over time, Oscar began to enjoy running. 412
# LABEL: He was glad to be getting in shape. 413
#
# DATA: He was glad to be getting in shape. 413
# LABEL: Breast Cancer 414
#
# DATA: Breast Cancer 414
# LABEL: Jill went to the doctor for her annual exam. 415
#
# DATA: Jill went to the doctor for her annual exam. 415
# LABEL: A lump was found on her breast and she needed more testing. 416
#
# DATA: A lump was found on her breast and she needed more testing. 416
# LABEL: She went to a follow up appointment and it was confirmed as cancer. 417
#
# DATA: She went to a follow up appointment and it was confirmed as cancer. 417
# LABEL: Jill went through several rounds of chemotherapy. 418
#
# DATA: Jill went through several rounds of chemotherapy. 418
# LABEL: Fortunately, she had no signs of cancer following her treatment. 419
#
# DATA: Fortunately, she had no signs of cancer following her treatment. 419
# LABEL: homework 420
#
# DATA: homework 420
# LABEL: Jasmine had homework to do. 421
#
# DATA: Jasmine had homework to do. 421
# LABEL: She did not have a pencil. 422
#
# DATA: She did not have a pencil. 422
# LABEL: She looked around the room for one. 423
#
# DATA: She looked around the room for one. 423
# LABEL: The room did not have a pencil. 424
#
# DATA: The room did not have a pencil. 424
# LABEL: Jasmine decided not to do her homework. 425
#
# DATA: Jasmine decided not to do her homework. 425
# LABEL: Marc's Absence 426
#
# DATA: Marc's Absence 426
# LABEL: Marc always had perfect attendance at school. 427
#
# DATA: Marc always had perfect attendance at school. 427
# LABEL: One day, he stopped coming to class. 428
#
# DATA: One day, he stopped coming to class. 428
# LABEL: Everyone was worried about him! 429
#
# DATA: Everyone was worried about him! 429
# LABEL: He came back a few days later. 430
#
# DATA: He came back a few days later. 430
# LABEL: He had been in bed with the flu. 431
#
# DATA: He had been in bed with the flu. 431
# LABEL: Joe and Santa Claus 432
#
# DATA: Joe and Santa Claus 432
# LABEL: Joe was really excited for Christmas. 433
#
# DATA: Joe was really excited for Christmas. 433
# LABEL: Joe has never seen Santa Claus before. 434
#
# DATA: Joe has never seen Santa Claus before. 434
# LABEL: He decided to hide on top of the staircase to try to catch Santa. 435
#
# DATA: He decided to hide on top of the staircase to try to catch Santa. 435
# LABEL: Joe waited as long as he could before he fell asleep. 436
#
# DATA: Joe waited as long as he could before he fell asleep. 436
# LABEL: He woke up to many presents under the tree, and no Santa in sight! 437
#
# DATA: He woke up to many presents under the tree, and no Santa in sight! 437
# LABEL: Apples 438
#
# DATA: Apples 438
# LABEL: Anna went to pick apples. 439
#
# DATA: Anna went to pick apples. 439
# LABEL: She tried to pluck the low-hanging fruits. 440
#
# DATA: She tried to pluck the low-hanging fruits. 440
# LABEL: But she could reach very few. 441
#
# DATA: But she could reach very few. 441
# LABEL: At the end of the trip, she had only ten apples. 442
#
# DATA: At the end of the trip, she had only ten apples. 442
# LABEL: Anna wished she had been able to reach more apples! 443
#
# DATA: Anna wished she had been able to reach more apples! 443
# LABEL: Rubber Garden 444
#
# DATA: Rubber Garden 444
# LABEL: Bob bought a new manufactured home in Montana. 445
#
# DATA: Bob bought a new manufactured home in Montana. 445
# LABEL: He was sad he didn't have any land to grow a garden on. 446
#
# DATA: He was sad he didn't have any land to grow a garden on. 446
# LABEL: One of his neighbors told him he could vegetables in tires. 447
#
# DATA: One of his neighbors told him he could vegetables in tires. 447
# LABEL: Bob tried it and was astounded when it worked. 448
#
# DATA: Bob tried it and was astounded when it worked. 448
# LABEL: He's very proud of his tire grown tomatoes and corn. 449
#
# DATA: He's very proud of his tire grown tomatoes and corn. 449
# LABEL: The Poll 450
#
# DATA: The Poll 450
# LABEL: The candidates were running a tight campaign. 451
#
# DATA: The candidates were running a tight campaign. 451
# ...
# LABEL: Andy was excited that he was hired as the new art teacher! 2861
#
# DATA: Andy was excited that he was hired as the new art teacher! 2861
# LABEL: Dog problem 2862
#
# DATA: Dog problem 2862
# LABEL: Ken took his neighbor's dog for a walk. 2863
#
# DATA: Ken took his neighbor's dog for a walk. 2863
# LABEL: He played with the dog in the park for an hour. 2864
#
# DATA: He played with the dog in the park for an hour. 2864
# LABEL: When it was time to go home, he stopped for ice cream. 2865
#
# DATA: When it was time to go home, he stopped for ice cream. 2865
# LABEL: While Ken was paying for his ice cream cone, the dog got away. 2866
#
# DATA: While Ken was paying for his ice cream cone, the dog got away. 2866
# LABEL: Ken dropped the ice cream and run after the dog. 2867
#
# DATA: Ken dropped the ice cream and run after the dog. 2867
# LABEL: Linda gets a new friend 2868
#
# DATA: Linda gets a new friend 2868
# LABEL: One day linda was driving down the road tired from work. 2869
#
# DATA: One day linda was driving down the road tired from work. 2869
# LABEL: Her eyes were feeling heavy until she spotted something on the road. 2870
#
# DATA: Her eyes were feeling heavy until she spotted something on the road. 2870
# LABEL: It was a brown dog. 2871
#
# DATA: It was a brown dog. 2871
# LABEL: Linda decided to pick the pup up since it didn't have a collar. 2872
#
# DATA: Linda decided to pick the pup up since it didn't have a collar. 2872
# LABEL: Linda and the dog became best friends. 2873
#
# DATA: Linda and the dog became best friends. 2873
# LABEL: Infinite Jest Footnotes 2874
#
# DATA: Infinite Jest Footnotes 2874
# LABEL: I started reading Infinite Jest last week. 2875
#
# DATA: I started reading Infinite Jest last week. 2875
# LABEL: It is a 1,078 page novel. 2876
#
# DATA: It is a 1,078 page novel. 2876
# LABEL: I was into page 300 when I realized the author wrote footnotes. 2877
#
# DATA: I was into page 300 when I realized the author wrote footnotes. 2877
# LABEL: It took me two hours to catch up on the footnotes. 2878
#
# DATA: It took me two hours to catch up on the footnotes. 2878
# LABEL: I am on page 700, and will be relieved to finish this wild novel. 2879
#
# DATA: I am on page 700, and will be relieved to finish this wild novel. 2879
# LABEL: A Day of Skiing 2880
#
# DATA: A Day of Skiing 2880
# LABEL: The Wheeler family were very happy. 2881
#
# DATA: The Wheeler family were very happy. 2881
# LABEL: They were on a wonderful ski trip out West. 2882
#
# DATA: They were on a wonderful ski trip out West. 2882
# LABEL: The Wheelers were skiing and having a wonderful time. 2883
#
# DATA: The Wheelers were skiing and having a wonderful time. 2883
# LABEL: They all skied down so many slopes. 2884
#
# DATA: They all skied down so many slopes. 2884
# LABEL: The entire family felt closer and had a very good trip. 2885
#
# DATA: The entire family felt closer and had a very good trip. 2885
# LABEL: An Unusual Trip to the Cinema 2886
#
# DATA: An Unusual Trip to the Cinema 2886
# LABEL: My boyfriend and I decided to go see a new movie. 2887
#
# DATA: My boyfriend and I decided to go see a new movie. 2887
# LABEL: We went to the theater and purchased the tickets. 2888
#
# DATA: We went to the theater and purchased the tickets. 2888
# LABEL: We really wanted to see a specific movie. 2889
#
# DATA: We really wanted to see a specific movie. 2889
# LABEL: We entered the theater and found it was the wrong movie playing. 2890
#
# DATA: We entered the theater and found it was the wrong movie playing. 2890
# LABEL: We went back to the entrance and was able to see the correct movie. 2891
#
# DATA: We went back to the entrance and was able to see the correct movie. 2891
# LABEL: The Navy 2892
#
# DATA: The Navy 2892
# LABEL: Ben wanted to be in the Navy. 2893
#
# DATA: Ben wanted to be in the Navy. 2893
# LABEL: He trained all week to get more fit. 2894
#
# DATA: He trained all week to get more fit. 2894
# LABEL: Ben decided that it was too hard and wanted to quit. 2895
#
# DATA: Ben decided that it was too hard and wanted to quit. 2895
# LABEL: His mother told him to never quit. 2896
#
# DATA: His mother told him to never quit. 2896
# LABEL: Ben signed up and passed his fitness test! 2897
#
# DATA: Ben signed up and passed his fitness test! 2897
# LABEL: The Dinner 2898
#
# DATA: The Dinner 2898
# LABEL: Marvin asked his wife to prepare a dinner for his business associates. 2899
#
# DATA: Marvin asked his wife to prepare a dinner for his business associates. 2899
# LABEL: She wasn't a very good cook, so she called a restaurant. 2900
#
# DATA: She wasn't a very good cook, so she called a restaurant. 2900
# LABEL: They brought her a catered meal. 2901
#
# DATA: They brought her a catered meal. 2901
# LABEL: All the guests raved about the food. 2902
#
# DATA: All the guests raved about the food. 2902
# LABEL: She just smiled and pretended she'd made it all. 2903
#
# DATA: She just smiled and pretended she'd made it all. 2903
# LABEL: Smith Family Trip 2904
#
# DATA: Smith Family Trip 2904
# LABEL: The smith's wanted to get away. 2905
#
# DATA: The smith's wanted to get away. 2905
# LABEL: They decided to travel to the Bahama's. 2906
#
# DATA: They decided to travel to the Bahama's. 2906
# LABEL: The family had the best time swimming and surfing. 2907
#
# DATA: The family had the best time swimming and surfing. 2907
# LABEL: They had the time of their lives. 2908
#
# DATA: They had the time of their lives. 2908
# LABEL: The smith family decided the Bahama's would be their tradition. 2909
#
# DATA: The smith family decided the Bahama's would be their tradition. 2909
# LABEL: The Roadtrip 2910
#
# DATA: The Roadtrip 2910
# LABEL: The couple had never driven cross-country. 2911
#
# DATA: The couple had never driven cross-country. 2911
# LABEL: They set out on a Sunday and planned to travel for a month. 2912
#
# DATA: They set out on a Sunday and planned to travel for a month. 2912
# LABEL: The drive got very boring after a few days. 2913
#
# DATA: The drive got very boring after a few days. 2913
# LABEL: Instead of continuing on, they decided to give up and turn back. 2914
#
# DATA: Instead of continuing on, they decided to give up and turn back. 2914
# LABEL: THey were happy to be back in their own home. 2915
#
# DATA: THey were happy to be back in their own home. 2915
# LABEL: John burns the biscuits 2916
#
# DATA: John burns the biscuits 2916
# LABEL: John was having a get together with friends. 2917
#
# DATA: John was having a get together with friends. 2917
# LABEL: He was making his grandmother's biscuit recipe. 2918
#
# DATA: He was making his grandmother's biscuit recipe. 2918
# LABEL: Friends begin to arrive and John is all over the house. 2919
#
# DATA: Friends begin to arrive and John is all over the house. 2919
# LABEL: John greets and meets with all his friends. 2920
#
# DATA: John greets and meets with all his friends. 2920
# LABEL: John totally forgets about the biscuits until it's too late. 2921
#
# DATA: John totally forgets about the biscuits until it's too late. 2921
# LABEL: Salty People 2922
#
# DATA: Salty People 2922
# LABEL: I walked on campus and noticed a friend who I didn't see in a while. 2923
#
# DATA: I walked on campus and noticed a friend who I didn't see in a while. 2923
# LABEL: I tried to approach her in a friendly manner and say hi. 2924
#
# DATA: I tried to approach her in a friendly manner and say hi. 2924
# LABEL: When she saw her, she had a bad grin on her face. 2925
#
# DATA: When she saw her, she had a bad grin on her face. 2925
# LABEL: She remembers me however, she rushed our conversation. 2926
#
# DATA: She remembers me however, she rushed our conversation. 2926
# LABEL: Afterwards, she quickly walked away. 2927
#
# DATA: Afterwards, she quickly walked away. 2927
# LABEL: The Magician 2928
#
# DATA: The Magician 2928
# LABEL: The couple had never gone to a magic show before. 2929
#
# DATA: The couple had never gone to a magic show before. 2929
# LABEL: They were excited to see what would happen. 2930
#
# DATA: They were excited to see what would happen. 2930
# LABEL: The magician came out and began to perform his tricks. 2931
#
# DATA: The magician came out and began to perform his tricks. 2931
# LABEL: They were amazed and loved every second. 2932
#
# DATA: They were amazed and loved every second. 2932
# LABEL: The couple had a wonderful time and both agreed to go again. 2933
#
# DATA: The couple had a wonderful time and both agreed to go again. 2933
# LABEL: Jasper Eats A Gyro 2934
#
# DATA: Jasper Eats A Gyro 2934
# LABEL: Jasper has been working all afternoon and is quite hungry. 2935
#
# DATA: Jasper has been working all afternoon and is quite hungry. 2935
# LABEL: He decides to take a break and eat a gyro. 2936
#
# DATA: He decides to take a break and eat a gyro. 2936
# LABEL: Jasper buys a gyro from the restaurant near his office. 2937
#
# DATA: Jasper buys a gyro from the restaurant near his office. 2937
# LABEL: After eating it, he feels ready to work again. 2938
#
# DATA: After eating it, he feels ready to work again. 2938
# LABEL: He's glad that he no longer feels so hungry. 2939
#
# DATA: He's glad that he no longer feels so hungry. 2939
# LABEL: The Turtle 2940
#
# DATA: The Turtle 2940
# LABEL: The kids had a pet turtle. 2941
#
# DATA: The kids had a pet turtle. 2941
# LABEL: It was green with a big shell. 2942
#
# DATA: It was green with a big shell. 2942
# LABEL: They fed it carrots every night. 2943
#
# DATA: They fed it carrots every night. 2943
# LABEL: They worried that he was lonely. 2944
#
# DATA: They worried that he was lonely. 2944
# LABEL: They bought a second turtle to keep him company. 2945
#
# DATA: They bought a second turtle to keep him company. 2945
# LABEL: Pizza Lasagna 2946
#
# DATA: Pizza Lasagna 2946
# LABEL: Xander loved totino's frozen pizza's. 2947
#
# DATA: Xander loved totino's frozen pizza's. 2947
# LABEL: He would always cook three at a time and eat them all. 2948
#
# DATA: He would always cook three at a time and eat them all. 2948
# LABEL: One day he got creative and stacked them on top of each other. 2949
#
# DATA: One day he got creative and stacked them on top of each other. 2949
# LABEL: He threw some cheese on it and made a pizza lasagna. 2950
#
# DATA: He threw some cheese on it and made a pizza lasagna. 2950
# LABEL: Xander now owns a million dollar company selling frozen pizza. 2951
#
# DATA: Xander now owns a million dollar company selling frozen pizza. 2951
# LABEL: The Game 2952
#
# DATA: The Game 2952
# LABEL: Ashley started playing an online game. 2953
#
# DATA: Ashley started playing an online game. 2953
# LABEL: She met a few people and liked to chat with them. 2954
#
# DATA: She met a few people and liked to chat with them. 2954
# LABEL: She got sucked into the game and played many hours. 2955
#
# DATA: She got sucked into the game and played many hours. 2955
# LABEL: Soon, she was addicted. 2956
#
# DATA: Soon, she was addicted. 2956
# LABEL: She had to cancel her internet service to get her life back. 2957
#
# DATA: She had to cancel her internet service to get her life back. 2957
# LABEL: Plans Ruined 2958
#
# DATA: Plans Ruined 2958
# LABEL: I challenged my friend to a game of basketball. 2959
#
# DATA: I challenged my friend to a game of basketball. 2959
# LABEL: After several hours, rain drops started to pour from the sky. 2960
#
# DATA: After several hours, rain drops started to pour from the sky. 2960
# LABEL: Outside started to rain within seconds. 2961
#
# DATA: Outside started to rain within seconds. 2961
# LABEL: My friend and I ran to the car in the front parking lot. 2962
#
# DATA: My friend and I ran to the car in the front parking lot. 2962
# LABEL: We decided to visit another place. 2963
#
# DATA: We decided to visit another place. 2963
# LABEL: the vacuum 2964
#
# DATA: the vacuum 2964
# LABEL: Lisa bought a new vacuum. 2965
#
# DATA: Lisa bought a new vacuum. 2965
# LABEL: It sucked up her wedding ring! 2966
#
# DATA: It sucked up her wedding ring! 2966
# LABEL: She had to take it apart to find the ring. 2967
#
# DATA: She had to take it apart to find the ring. 2967
# LABEL: Now the vacuum is broken. 2968
#
# DATA: Now the vacuum is broken. 2968
# LABEL: Lisa learned an expensive lesson. 2969
#
# DATA: Lisa learned an expensive lesson. 2969
# LABEL: Beard 2970
#
# DATA: Beard 2970
# LABEL: My cousin's younger sister came to a wedding with a man. 2971
#
# DATA: My cousin's younger sister came to a wedding with a man. 2971
# LABEL: She was 40 and unmarried, although beautiful. 2972
#
# DATA: She was 40 and unmarried, although beautiful. 2972
# LABEL: I had assumed she was a lesbian until I saw the man. 2973
#
# DATA: I had assumed she was a lesbian until I saw the man. 2973
# LABEL: My kids said he could be a beard, drawing a quizzical look. 2974
#
# DATA: My kids said he could be a beard, drawing a quizzical look. 2974
# LABEL: They explained a beard is a male cover. 2975
#
# DATA: They explained a beard is a male cover. 2975
# LABEL: Unexpected Squirrel 2976
#
# DATA: Unexpected Squirrel 2976
# LABEL: The family had finally picked out a Christmas tree. 2977
#
# DATA: The family had finally picked out a Christmas tree. 2977
# LABEL: They spent half a day searching at six different tree lots. 2978
#
# DATA: They spent half a day searching at six different tree lots. 2978
# LABEL: Don't put the tree in the living room to sit before decorating it. 2979
#
# DATA: Don't put the tree in the living room to sit before decorating it. 2979
# LABEL: All of a sudden he noticed movement in the branches. 2980
#
# DATA: All of a sudden he noticed movement in the branches. 2980
# LABEL: There was a squirrel that had been living in the tree! 2981
#
# DATA: There was a squirrel that had been living in the tree! 2981
# LABEL: The Hurricane 2982
#
# DATA: The Hurricane 2982
# LABEL: The news warned that a strong hurricane was coming. 2983
#
# DATA: The news warned that a strong hurricane was coming. 2983
# LABEL: The forecaster stated that everyone should evacuate their homes. 2984
#
# DATA: The forecaster stated that everyone should evacuate their homes. 2984
# LABEL: Harold stubbornly refused to evacuate and stayed home. 2985
#
# DATA: Harold stubbornly refused to evacuate and stayed home. 2985
# LABEL: The hurricane came and ravaged many parts of the area. 2986
#
# DATA: The hurricane came and ravaged many parts of the area. 2986
# LABEL: Harold was lucky and his home suffered minor damage. 2987
#
# DATA: Harold was lucky and his home suffered minor damage. 2987
# LABEL: New Cast 2988
#
# DATA: New Cast 2988
# LABEL: Susie broke her ankle and went to the orthopedic doctor. 2989
#
# DATA: Susie broke her ankle and went to the orthopedic doctor. 2989
# LABEL: The doctor gave her options for a new cast color for her ankle. 2990
#
# DATA: The doctor gave her options for a new cast color for her ankle. 2990
# LABEL: Susie chose pink, to compliment her outfit. 2991
#
# DATA: Susie chose pink, to compliment her outfit. 2991
# LABEL: The doctor used a special saw to take the old cast off. 2992
#
# DATA: The doctor used a special saw to take the old cast off. 2992
# LABEL: Then, the doctor put a new pink cast on Susie's ankle. 2993
#
# DATA: Then, the doctor put a new pink cast on Susie's ankle. 2993
# LABEL: Grass Isn't Always Greener 2994
#
# DATA: Grass Isn't Always Greener 2994
# LABEL: Stan hated living in a small town. 2995
#
# DATA: Stan hated living in a small town. 2995
# LABEL: He spent hours working on his resume and applying to jobs. 2996
#
# DATA: He spent hours working on his resume and applying to jobs. 2996
# LABEL: Because of his hard work, he found a job in a big city. 2997
#
# DATA: Because of his hard work, he found a job in a big city. 2997
# LABEL: Stan was thrilled to leave his small town and start his big city job. 2998
#
# DATA: Stan was thrilled to leave his small town and start his big city job. 2998
# LABEL: After a few months, Stan became homesick for small town life. 2999
#
# DATA: After a few months, Stan became homesick for small town life. 2999
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11752\4095068947.py in <module>
#      13 for i,j in enumerate(test_vectors):
#      14     get_nearest(test_vectors[i], test_vectors, test_sentences, k=1)
# ---> 15     print("LABEL:", test_sentences[i+1], i+1, end="\n\n")
#
# IndexError: index 3000 is out of bounds for axis 0 with size 3000
