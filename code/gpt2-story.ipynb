# %% [markdown]
# <a href="https://colab.research.google.com/github/unicorn-yh/Story-Generation-NLP/blob/main/gpt2-story.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
data_path = '/content/gdrive/MyDrive/story_generation_dataset/'
# Out:
# Mounted at /content/gdrive

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 13.1 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 53.1 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 72.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
import os, time
import pickle
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2Tokenizer, PreTrainedTokenizer, GPT2LMHeadModel
from transformers.optimization import AdamW, get_linear_schedule_with_warmup

# %%
# The code for tokenizing the text and storing it in files is imported here
def tokenize_longform_text(raw_text_paths: list,
                           tokenizer: PreTrainedTokenizer,
                           block_size: int,
                           drop_last=True,
                           overlap=True):
    """ Loads raw LONGFORM text from a list of paths to text files, tokenizes it, splits the tokenized
     text into training examples and returns the list. Requires passing in a HuggingFace Transformers
     pretrained tokenizer"""

    # TODO: Look into methods of text augmentation, put this in as a placeholder

    # find correct block size of the tokenizer
    block_size = block_size - (tokenizer.model_max_length - tokenizer.max_len_single_sentence)

    # check that all the text file paths actually files
    for text_file in raw_text_paths:
        assert os.path.isfile(text_file), "{} is not a file".format(text_file)

    # make empty list to store all the examples
    examples = []

    # loop over all text files
    for text_file in raw_text_paths:

        with open(text_file, encoding="utf-8") as f:
            try:
                text = f.read()
                tokenized_text = tokenizer.convert_tokens_to_ids(tokenizer.tokenize(text))
                print("{} successfully read and tokenized".format(text_file))
            except:
                print("Error reading or tokenizing file {}".format(text_file))

        # check that the tokenized file is at least one block size long
        len_tokens = len(tokenized_text)
        print(len_tokens)
        if len_tokens < block_size:
            print("File {} is too short for the block size".format(text_file))
            pass

        try:
            if overlap is False:
                for i in range(0, len_tokens - block_size + 1, block_size):  # don't overlap examples
                    examples.append(tokenizer.build_inputs_with_special_tokens(tokenized_text[i:i + block_size]))
            else:  # overlap examples
                for i in range(0, len_tokens - block_size + 1, int(block_size / 2)):
                    examples.append(tokenizer.build_inputs_with_special_tokens(tokenized_text[i:i + block_size]))

            if drop_last is False:
                examples.append(tokenizer.build_inputs_with_special_tokens(tokenized_text[-block_size:]))

            print("Successfully split tokens from file {} into examples".format(text_file))
        except:
            print("Failed at splitting tokens from file {} into examples".format(text_file))

    print("{} examples total tokenized".format(len(examples)))

    return examples

# %%
def make_tokenized_examples(tokenizer: PreTrainedTokenizer,
                            block_size: int,
                            root_dir_path: str,
                            examples_file=None):
    """Tokenize a directory of text where the raw text is in a subdirectory '/raw_text' and the default
    is to put the tokenized text into a sub directory '/tokenized_examples' """

    # -------------------------------------------------------------------------------------------------------------
    # Do a bunch of error checking, finding text files and making output file names
    # -------------------------------------------------------------------------------------------------------------

    # check that root_dir_path is actually a path
    assert os.path.isdir(root_dir_path), "{} is not a directory".format(root_dir_path)
    # and check that we didn't accidentally put a / at the end of the dir path
    if not os.path.split(root_dir_path)[1]:
        root_dir_path = os.path.split(root_dir_path)[0]

    # check that there is a raw_text directory
    raw_dir_path = os.path.join(root_dir_path, "raw_text")
    assert os.path.isdir(raw_dir_path), "{} has no raw_text/ subdirectory".format(root_dir_path)

    # check that there are text files in there and if so get their names
    file_list = []
    for file in os.listdir(raw_dir_path):
        if file.endswith(".txt"):
            file_list.append(os.path.join(raw_dir_path, file))
    if len(file_list) == 0:
        raise RuntimeError("No text files found in {}".format(raw_dir_path))

    # now get the tokenized text file name, make the tokenized_text directory if necessary

    if examples_file is None:
        tokenized_dir = os.path.join(root_dir_path, "tokenized_examples")
        if not os.path.isdir(tokenized_dir):
            os.mkdir(tokenized_dir)

        print(root_dir_path)
        print(os.path.split(root_dir_path))

        author_name = os.path.split(root_dir_path)[1]
        examples_file = "examples_gpt2_blocksize_{}_{}.pkl".format(block_size, author_name)
        examples_file = os.path.join(tokenized_dir, examples_file)

    else:
        assert type(examples_file) is str, "tokenized_file_name must be a string or None"
        tokenized_dir = os.path.split(examples_file)[0]
        assert os.path.isdir(tokenized_dir), "{} is not a directory".format(tokenized_dir)

    # -------------------------------------------------------------------------------------------------------------
    # After all that make the examples and save them
    # -------------------------------------------------------------------------------------------------------------

    # tokenize all the files, split them into examples and concatenate them
    examples = tokenize_longform_text(file_list, tokenizer, block_size, drop_last=False, overlap=True)

    # save them as a pickle
    with open(examples_file, 'wb') as f:
        pickle.dump(examples, f, protocol=pickle.HIGHEST_PROTOCOL)

    print("{} examples created and saved in {}".format(len(examples), examples_file))

# %%
import pandas as pd 
train_stories = pd.read_csv(data_path+"ROCStories_train.csv", encoding="utf8")
test_stories = pd.read_csv(data_path+"ROCStories_test.csv", encoding="utf8")

# %%
index = 1
for data in train_stories.values[:2000,1:]:
    with open(data_path+"data/train/raw_text/"+str(index)+".txt","w") as file:
        for sent in data:
            file.write(sent+ r'\r\n\ '[:-1])
    file.close()
    index += 1

index = 1
for data in train_stories.values[:500,1:]:
    with open(data_path+"data/test/raw_text/"+str(index)+".txt","w") as file:
        for sent in data:
            file.write(sent+ r'\r\n\ '[:-1])
    file.close()
    index += 1

# %%
# import the tokenizer from the Transformers library
gpt2_tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# Out:
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %%
train_path = data_path+'data/train/'
test_path = data_path+'data/test/'
make_tokenized_examples(gpt2_tokenizer,10, train_path, examples_file=None);
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1335.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1335.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1336.txt successfully read and tokenized
# 71
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1336.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1337.txt successfully read and tokenized
# 74
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1337.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1338.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1338.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1339.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1339.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1341.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1341.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1340.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1340.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1342.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1342.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1343.txt successfully read and tokenized
# 79
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1343.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1344.txt successfully read and tokenized
# 68
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1344.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1346.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1346.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1345.txt successfully read and tokenized
# 94
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1345.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1347.txt successfully read and tokenized
# 85
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1347.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1348.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1348.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1349.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1349.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1350.txt successfully read and tokenized
# 72
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1350.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1351.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1351.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1352.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1352.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1353.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1353.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1354.txt successfully read and tokenized
# 72
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1354.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1355.txt successfully read and tokenized
# 98
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1355.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1357.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1357.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1356.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1356.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1359.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1359.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1358.txt successfully read and tokenized
# 93
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1358.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1360.txt successfully read and tokenized
# 65
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1360.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1361.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1361.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1363.txt successfully read and tokenized
# 74
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1363.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1364.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1364.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1362.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1362.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1365.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1365.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1367.txt successfully read and tokenized
# 77
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1367.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1366.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1366.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1368.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1368.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1369.txt successfully read and tokenized
# 73
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1369.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1370.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1370.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1371.txt successfully read and tokenized
# 88
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1371.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1374.txt successfully read and tokenized
# 73
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1374.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1373.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1373.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1372.txt successfully read and tokenized
# 74
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1372.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1375.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1375.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1376.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1376.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1377.txt successfully read and tokenized
# 101
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1377.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1379.txt successfully read and tokenized
# 98
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1379.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1378.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1378.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1381.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1381.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1380.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1380.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1382.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1382.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1383.txt successfully read and tokenized
# 94
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1383.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1384.txt successfully read and tokenized
# 70
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1384.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1386.txt successfully read and tokenized
# 73
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1386.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1385.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1385.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1387.txt successfully read and tokenized
# 77
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1387.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1388.txt successfully read and tokenized
# 100
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1388.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1389.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1389.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1390.txt successfully read and tokenized
# 79
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1390.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1391.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1391.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1392.txt successfully read and tokenized
# 98
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1392.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1394.txt successfully read and tokenized
# 93
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1394.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1393.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1393.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1395.txt successfully read and tokenized
# 85
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1395.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1396.txt successfully read and tokenized
# 88
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1396.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1397.txt successfully read and tokenized
# 69
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1397.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1398.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1398.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1399.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1399.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1400.txt successfully read and tokenized
# 105
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1400.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1401.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1401.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1402.txt successfully read and tokenized
# 99
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1402.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1403.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1403.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1404.txt successfully read and tokenized
# 75
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1404.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1405.txt successfully read and tokenized
# 95
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1405.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1406.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1406.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1408.txt successfully read and tokenized
# 77
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1408.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1407.txt successfully read and tokenized
# 106
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1407.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1409.txt successfully read and tokenized
# 72
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1409.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1410.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1410.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1411.txt successfully read and tokenized
# 85
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1411.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1413.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1413.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1412.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1412.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1414.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1414.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1415.txt successfully read and tokenized
# 85
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1415.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1416.txt successfully read and tokenized
# 105
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1416.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1418.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1418.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1419.txt successfully read and tokenized
# 79
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1419.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1417.txt successfully read and tokenized
# 75
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1417.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1420.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1420.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1421.txt successfully read and tokenized
# 100
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1421.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1422.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1422.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1423.txt successfully read and tokenized
# 67
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1423.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1425.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1425.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1426.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1426.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1424.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1424.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1427.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1427.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1428.txt successfully read and tokenized
# 72
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1428.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1429.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1429.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1430.txt successfully read and tokenized
# 72
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1430.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1431.txt successfully read and tokenized
# 107
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1431.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1433.txt successfully read and tokenized
# 79
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1433.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1432.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1432.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1434.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1434.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1435.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1435.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1436.txt successfully read and tokenized
# 95
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1436.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1437.txt successfully read and tokenized
# 95
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1437.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1438.txt successfully read and tokenized
# 67
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1438.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1439.txt successfully read and tokenized
# 94
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1439.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1440.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1440.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1441.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1441.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1442.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1442.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1443.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1443.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1444.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1444.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1445.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1445.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1447.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1447.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1446.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1446.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1448.txt successfully read and tokenized
# 100
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1448.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1449.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1449.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1451.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1451.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1450.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1450.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1452.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1452.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1453.txt successfully read and tokenized
# 105
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1453.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1454.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1454.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1455.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1455.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1456.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1456.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1457.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1457.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1459.txt successfully read and tokenized
# 98
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1459.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1460.txt successfully read and tokenized
# 100
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1460.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1458.txt successfully read and tokenized
# 88
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1458.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1461.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1461.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1462.txt successfully read and tokenized
# 85
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1462.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1463.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1463.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1464.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1464.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1465.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1465.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1466.txt successfully read and tokenized
# 77
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1466.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1467.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1467.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1469.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1469.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1468.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1468.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1470.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1470.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1472.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1472.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1471.txt successfully read and tokenized
# 98
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1471.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1473.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1473.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1474.txt successfully read and tokenized
# 88
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1474.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1475.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1475.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1476.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1476.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1478.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1478.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1477.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1477.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1479.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1479.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1480.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1480.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1482.txt successfully read and tokenized
# 93
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1482.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1481.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1481.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1483.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1483.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1484.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1484.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1485.txt successfully read and tokenized
# 75
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1485.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1486.txt successfully read and tokenized
# 88
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1486.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1487.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1487.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1488.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1488.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1489.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1489.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1490.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1490.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1491.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1491.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1492.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1492.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1493.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1493.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1494.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1494.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1495.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1495.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1496.txt successfully read and tokenized
# 72
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1496.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1497.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1497.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1498.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1498.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1499.txt successfully read and tokenized
# 85
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1499.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1500.txt successfully read and tokenized
# 95
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1500.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1501.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1501.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1502.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1502.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1503.txt successfully read and tokenized
# 68
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1503.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1504.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1504.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1505.txt successfully read and tokenized
# 99
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1505.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1506.txt successfully read and tokenized
# 101
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1506.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1507.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1507.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1508.txt successfully read and tokenized
# 97
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1508.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1509.txt successfully read and tokenized
# 94
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1509.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1510.txt successfully read and tokenized
# 95
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1510.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1511.txt successfully read and tokenized
# 104
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1511.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1512.txt successfully read and tokenized
# 72
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1512.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1514.txt successfully read and tokenized
# 88
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1514.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1513.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1513.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1515.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1515.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1516.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1516.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1517.txt successfully read and tokenized
# 94
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1517.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1518.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1518.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1519.txt successfully read and tokenized
# 93
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1519.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1520.txt successfully read and tokenized
# 97
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1520.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1521.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1521.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1522.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1522.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1523.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1523.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1524.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1524.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1525.txt successfully read and tokenized
# 93
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1525.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1527.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1527.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1526.txt successfully read and tokenized
# 97
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1526.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1528.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1528.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1529.txt successfully read and tokenized
# 94
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1529.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1530.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1530.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1531.txt successfully read and tokenized
# 75
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1531.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1532.txt successfully read and tokenized
# 92
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1532.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1535.txt successfully read and tokenized
# 84
# ...
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/935.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/935.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/936.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/936.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/937.txt successfully read and tokenized
# 100
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/937.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/938.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/938.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/939.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/939.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/940.txt successfully read and tokenized
# 73
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/940.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/941.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/941.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/942.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/942.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/943.txt successfully read and tokenized
# 73
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/943.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/946.txt successfully read and tokenized
# 88
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/946.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/944.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/944.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/945.txt successfully read and tokenized
# 102
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/945.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/947.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/947.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/948.txt successfully read and tokenized
# 67
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/948.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/950.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/950.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/949.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/949.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/951.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/951.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/952.txt successfully read and tokenized
# 79
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/952.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/953.txt successfully read and tokenized
# 97
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/953.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/955.txt successfully read and tokenized
# 86
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/955.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/954.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/954.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/956.txt successfully read and tokenized
# 94
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/956.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/957.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/957.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/958.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/958.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/959.txt successfully read and tokenized
# 76
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/959.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/960.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/960.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/961.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/961.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/962.txt successfully read and tokenized
# 96
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/962.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/963.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/963.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/964.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/964.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/965.txt successfully read and tokenized
# 80
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/965.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/966.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/966.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/968.txt successfully read and tokenized
# 99
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/968.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/967.txt successfully read and tokenized
# 93
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/967.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/969.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/969.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/970.txt successfully read and tokenized
# 111
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/970.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/971.txt successfully read and tokenized
# 101
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/971.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/972.txt successfully read and tokenized
# 105
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/972.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/973.txt successfully read and tokenized
# 67
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/973.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/974.txt successfully read and tokenized
# 77
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/974.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/976.txt successfully read and tokenized
# 103
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/976.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/975.txt successfully read and tokenized
# 81
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/975.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/977.txt successfully read and tokenized
# 75
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/977.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/979.txt successfully read and tokenized
# 66
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/979.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/980.txt successfully read and tokenized
# 70
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/980.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/978.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/978.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/981.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/981.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/982.txt successfully read and tokenized
# 87
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/982.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/983.txt successfully read and tokenized
# 70
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/983.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/984.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/984.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/985.txt successfully read and tokenized
# 82
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/985.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/986.txt successfully read and tokenized
# 97
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/986.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/987.txt successfully read and tokenized
# 89
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/987.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/988.txt successfully read and tokenized
# 91
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/988.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/989.txt successfully read and tokenized
# 95
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/989.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/990.txt successfully read and tokenized
# 67
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/990.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/992.txt successfully read and tokenized
# 98
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/992.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/991.txt successfully read and tokenized
# 93
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/991.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/993.txt successfully read and tokenized
# 77
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/993.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/994.txt successfully read and tokenized
# 84
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/994.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/995.txt successfully read and tokenized
# 90
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/995.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/996.txt successfully read and tokenized
# 83
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/996.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/997.txt successfully read and tokenized
# 68
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/997.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/998.txt successfully read and tokenized
# 95
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/998.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1000.txt successfully read and tokenized
# 79
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/1000.txt into examples
# /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/999.txt successfully read and tokenized
# 78
# Successfully split tokens from file /content/gdrive/MyDrive/story_generation_dataset/data/train/raw_text/999.txt into examples
# 34047 examples total tokenized
# 34047 examples created and saved in /content/gdrive/MyDrive/story_generation_dataset/data/train/tokenized_examples/examples_gpt2_blocksize_10_train.pkl

# %%
class StoryData(torch.utils.data.Dataset):
    '''This is a class for loading in a list of tokenized gpt2 examples from a list of file paths'''

    def __init__(
            self,
            file_paths: list):

        for fpath in file_paths:
            assert os.path.isfile(fpath), "{} does not exist".format(fpath)

        self.examples = []

        for fpath in file_paths:
            with open(fpath, 'rb') as f:
                examps = pickle.load(f)
            self.examples.extend(examps)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, item):
        return torch.tensor(self.examples[item], dtype=torch.long)

# %%
file_paths = []
file_paths.append(os.path.join(data_path+'data/train/', "tokenized_examples/examples_gpt2_blocksize_10_train.pkl"))
print(file_paths)
# Out:
# ['/content/gdrive/MyDrive/story_generation_dataset/data/train/tokenized_examples/examples_gpt2_blocksize_10_train.pkl']

# %%
# make the actual instance of the Dataset class using the chosen authors 
story_dataset = StoryData(file_paths)

# make the data loader
#NOTE: the batch_size is 1 because we will be doing gradient accumulation. This is to get around the fact
# that I am using a 8GB RTX 2070 Super GPU which is small
story_dataloader = DataLoader(story_dataset, batch_size =1, shuffle = True)

# %%
# Pick a model to train

# distilgpt2 will on my 8GB GPU

model = GPT2LMHeadModel.from_pretrained('distilgpt2')

# gpt2-medium will not train on an 8GB GPU ... but you can generate text with the pre-trained model if you like.
# if you have a larger GPU, say a 24 GB RTX 3090 you may wish to try training though
# model = GPT2LMHeadModel.from_pretrained('gpt2-medium')

# NOTE: look into gradient checkpointing and see if that will allow for training within 8GB
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/353M [00:00<?, ?B/s]

# %%
# set epochs and batch size
N_EPOCHS = 5
BATCH_SIZE = 8 # note we are actually going to use gradient accumulation because these models are so big

# for the scheduler
LEARNING_RATE = 0.0001 #0.00002
WARMUP_STEPS = 100 # 10000

# %%
# put the model on the gpu. note if this doesn't say you're using the gpu this will not train!

device = 'cpu'
if torch.cuda.is_available():
    print('using gpu')
    device = 'cuda'
print('device:',device)

model.to(device)

# create optimizer
optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)
# Out:
# using gpu
# device: cuda
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# BEFORE
# make a function to generate text from the model

def generate_test_text(model, max_length=256, input_text=None):
    model.eval() # put the model in eval mode
    if input_text is None:
        input_text = "Once upon a time there was a little mouse."
    input_ids = gpt2_tokenizer.encode(input_text, return_tensors='pt')
    input_ids = input_ids.to('cuda')
    output_ids = model.generate(input_ids, 
                                pad_token_id=gpt2_tokenizer.eos_token_id,
                                max_length=max_length, 
                                do_sample=True, 
                                top_p=0.95, 
                                top_k=60,
                                num_return_sequences=1)

    output_text = gpt2_tokenizer.decode(output_ids[0])
    return output_text

# %%
# and do some generation. The output should be different every time you run this cell 
# and of all sorts of topics and styles
prompt ="once upon a time there was a little mouse" 
print(generate_test_text(model,input_text=prompt, max_length=256))
# Out:
# once upon a time there was a little mouse in the back and it was so long that it took more than a minute to open it.
# After you first opened the door the door opened and there was a long wooden door behind the door where the mouse was sitting. You could see the mouse sitting around as he tried to make sure he was sitting on a table to check what his body was doing.
# He turned and looked at him, and he looked down at the boy who was being held against the wall by the mouse and the boy who had suddenly entered on that one.
# "It is not all the same," he said and the boy slowly put it to the table. It was now the boy who had been in a position where his arms were getting stronger and so the boy sat and looked at him with his hands over his mouth.
# "Did you hear the voice?"
# "I am still trying to understand. It is quite strange. You say you never had a chance to be human and after a while no one can even talk to you about it. It doesn't seem to be true, even in this day and age, but I have experienced a lot and a lot of pleasure when you do so."
# "I didn't have time to

# %%
# make scheduler (for varying learning rate over time)
scheduler = get_linear_schedule_with_warmup(optimizer=optimizer, num_warmup_steps=WARMUP_STEPS, num_training_steps=-1)

# AFTER
# This is the link to the gradient accumulation documentation
# https://pytorch.org/docs/stable/notes/amp_examples.html#gradient-accumulation# 

#TODO: look into gradient checkpointing as well

epoch_loss = 0.0 # used to track loss for each epoch

internal_batch_count = 0 # used to track number of examples within each batch. This is necessary 
                         # because of the gradient accumulation hack (to deal with my 8GB GPU memory)
    
# make FP16 scaler for faster training
scaler = torch.cuda.amp.GradScaler()
    
# put the model into training mode
model.train()

for epoch in range(N_EPOCHS): # iterate over epochs
    
    print("started epoch {}".format(epoch))
    
    for idx, text in enumerate(story_dataloader):  # this data loader is set up to shuffle automatically

        # Do the forward propagation. 
        # Don't forget to put the text onto the gpu.
        # you have to put in labels to get the loss as an output.
        # because GPT is an autogregessive model the input is the output for training purposes
        
        with torch.cuda.amp.autocast():
            outputs = model(text.to(device), labels=(text.to(device)))
        
            # get the loss out so we can do backwards propagation
            loss, logits = outputs[:2]
            loss = loss / BATCH_SIZE 
        
        # do backpropagation. yay autodifferentiation!
        # note the use of the scaler for the FP16 
        scaler.scale(loss).backward()
        
        # keep track of the loss
        epoch_loss = epoch_loss + loss.detach().cpu().numpy()  # need to detach the gradients 
                                                               # because we only care about the numerical value
                                                               # also store the epoch loss on the cpu as numpy
            
        # increment the internal_batch_count
        internal_batch_count = internal_batch_count + 1
        
        # Now, if we have run through a full batch, take some optimizer and gradient steps
        if internal_batch_count == BATCH_SIZE:
            internal_batch_count = 0 # reset this
            
            # take an optimizer step. note the use of the scaler for FP16
            scaler.step(optimizer) 
            scaler.update()
            optimizer.zero_grad() # zero out the gradients in the optimizer
            
            model.zero_grad() # zero out the gradients we've been accumulating in the model
            
            scheduler.step() # take a scheduler step

     # Now that we've gone through an epoch, let's see what the loss is and what some generated text looks like
    
    # put the model into evaluation mode
    model.eval()
    
    # print the loss
    print("Epoch {} has loss {}".format(epoch, epoch_loss))
    # reset the loss
    epoch_loss = 0.0
    
    # uncomment this if you want to print some test text after each epoch
    #print(generate_test_text(model,input_text=prompt))
    
    
    # put the model back in training mode
    model.train()
# Out:
# started epoch 0
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch 0 has loss 13455.683310374618
# started epoch 1
# Epoch 1 has loss 13352.844423286617
# started epoch 2
# Epoch 2 has loss 13353.959836542606
# started epoch 3
# Epoch 3 has loss 13346.500084221363
# started epoch 4
# Epoch 4 has loss 13358.591995038092

# %%
def strip_paragraph(paragraph, sentence=6):
    sent_count = 0
    output_str = ""
    for i in range(len(paragraph)):
        output_str += paragraph[i]
        if paragraph[i] == '.' and paragraph[i+1] == ' ':
            sent_count += 1
        if sent_count == 5:
            break
    return output_str

# %%
test_ls = np.loadtxt(data_path+"test-index.txt")
train_array = train_stories.values[:,1:].reshape(-1).tolist()
with open(data_path+"output/gpt2-generated-story.txt","w") as file:
    for i in range(20):
        output_text = ""
        index = int(test_ls[i])
        prompt = train_array[index] 
        text = str(generate_test_text(model,input_text=prompt, max_length=256)).replace('\\','').replace('rn',' ')
        text = strip_paragraph(text,sentence=6)
        output_text += "Original story: " + prompt + "\n"
        output_text += "Generated story: " + text + "\n\n"
        file.write(output_text)
        print(output_text)
file.close()
# Out:
# Original story: We had no reservations and had to sit at the bar.
# Generated story: We had no reservations and had to sit at the bar. A friend of mine worked a lot harder with a new artist. My girlfriend wanted a shot of my new piece. The girl was an experienced artist. She got a great story from our local artists.
#
#
# Original story: I dreamed my friend's daughter broke up with her boyfriend.
# Generated story: I dreamed my friend's daughter broke up with her boyfriend. I went to the doctor and got the surgery. After the surgery, she was so happy. My husband took up the exam at the University of Georgia in 2008. His father gave a test.
#
#
# Original story: Everyone told me to try it.
# Generated story: Everyone told me to try it. I‍It was very difficult. I woke up to get nervous and tired and woke up the next mo ing. I knew that I couldn't get out of bed because of the music. I realized that my friend had gone to work.
#
#
# Original story: Neither one of them could get the nerve to throw a punch.
# Generated story: Neither one of them could get the nerve to throw a punch. She said, "It's going to be fun for them to fight at home." They played basketball together and went to the games again. John called to say to him, "I should be able to beat the bad guys on the court and get their ticket for the win. They were watching at home and they couldn't believe it. They bought beer in a special place and ate hot dogs.
#
#
# Original story: Mary is pregnant.
# Generated story: Mary is pregnant. MarynMartha was happy, her boyfriend was happy. Martha was excited. He saw her with his boyfriend. Mary liked her new boyfriend.
#
#
# Original story: Rhonda thought the world was against her but was determined.
# Generated story: Rhonda thought the world was against her but was determined. He went to her family and bought a truck to make ends meet. Tommy decided that they would make a difference. Tommy made his family and became friends. Tommy's car was the one that made his trip! Tommy and Tom made all the friends along the way.
#
#
# Original story: He liked to feel more important than anyone else.
# Generated story: He liked to feel more important than anyone else. Sometime before the first movie was set it was going to start with one movie. He bought the theater and bought a theater. After watching the movie he decided to go get a ticket. When his daughter got home he decided to go to the game to take a game.
#
#
# Original story: They day came and they went to the race.
# Generated story: They day came and they went to the race. As a puppy, everyone was happy. He worked hard, and they couldn't afford a dog. He went to school and spent a year at the zoo. They took their vacation all year with him.
#
#
# Original story: Sarah's girlfriend just wandered around the neighborhood aimlessly.
# Generated story: Sarah's girlfriend just wandered around the neighborhood aimlessly. John figured if his girlfriend would do a good job of making her stop, he'd go through a fine job working a busy job. My new friend decided to work out more. I started to go shopping. My friend wanted to buy a bike.
#
#
# Original story: Maria went inside and put her takeaway on the kitchen table.
# Generated story: Maria went inside and put her takeaway on the kitchen table. Jenna made fun of everything and wanted to go the rest of her day, and they ate breakfast. When the day finished they decided to celebrate. They didn't care that they'd been missing. She worked hard.
#
#
# Original story: Mark attempted to call her, but she would not answer.
# Generated story: Mark attempted to call her, but she would not answer. I was working hard to make the best. At that point, I decided to go to sleep and work hard to ea  the money. He worked harder than other people, and he was no longer able to ea  enough to make the necessary living. He spent the whole time helping people.
#
#
# Original story: Barry was pleased to see the park would be finished by December.
# Generated story: Barry was pleased to see the park would be finished by December. Tommy is proud that he had found his way into the park. Tommy is proud that he had found his way into the park. Tommy's favorite park was the White Pine Tree. Tommy is excited that he could be found while camping! He loves what he's doing.
#
#
# Original story: Larry was thinking of cheating on his test.
# Generated story: Larry was thinking of cheating on his test. Tom loved the test. Tom hated it and spent some time thinking on it. Tom was so happy when he saw the test, it didn't make his time. Tom knew he could get the test, so he hired a real test coordinator to take the test.
#
#
# Original story: Dad was too cold, Mom was too warm, and the kids also could not agree.
# Generated story: Dad was too cold, Mom was too warm, and the kids also could not agree. My mom went to the kitchen and ordered some treats on her favorite cup of coffee. She said she couldn't stop, and was afraid of her dad. They were in bed, and she was so happy. Mom's favorite cup of coffee is a hot coffee! Bobby was always happy with his birthday.
#
#
# Original story: They had agreed on a Mexican restaurant.
# Generated story: They had agreed on a Mexican restaurant. When he was home, he decided to eat. After hearing a great story, he decided to do a video project. The music was good and everyone loved the music. It was great to watch the movie when people played.
#
#
# Original story: Bob was on the phone all day.
# Generated story: Bob was on the phone all day. Mike is at work right now and can't take a nap. He went to sleep and woke up early so that he was still asleep. His mom called and got him to work to cheer him on. Mike took a nap on the mo ing but never found any sleep at all.
#
#
# Original story: Cathy decided it would be fun to have a dunk tank.
# Generated story: Cathy decided it would be fun to have a dunk tank. Eddie, it was the best, but the watermelon didn't smell great. Bob was very excited to show off what he could do next. Bob had had told everyone it would be fun for them to play the game. The winning team was great.
#
#
# Original story: He decided he might like to get a seeing eye dog.
# Generated story: He decided he might like to get a seeing eye dog. He loves to play with a cat, so he decided to try and pick his favorite cat. My mom said that it was his favorite cat. She wanted to get a good cat. She played at school every day, so she decided to visit her favorite cat.
#
#
# Original story: He punched a hole in the wall of his house.
# Generated story: He punched a hole in the wall of his house. She told him to take a nap. She went over the bathroom. When she woke he realized that he had to cut it. She gave her two napkins to friends and friends and took them home.
#
#
# Original story: She answered the calls, ruining the proposal.
# Generated story: She answered the calls, ruining the proposal. John was tired of waiting on the next step. After spending time in the bathroom, nShe asked her coworkers to make their dinner. They were so frustrated with John. John thought his coworkers would just make breakfast.
